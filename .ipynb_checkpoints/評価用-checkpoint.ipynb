# %% [markdown]
# Unity Communication

# %%
import sys
sys.path.append('../simulation/')
from unity_simulator.comm_unity import UnityCommunication
comm = UnityCommunication()
comm.reset(0)
# Out:
# True

# %% [markdown]
# Action List

# %%
import csv
from email import header

csv_file = open("./action_list.csv", "r", encoding="ms932", errors="", newline="" )
f = csv.reader(csv_file, delimiter=",", doublequote=True, lineterminator="\r\n", quotechar='"', skipinitialspace=True)

action_list = [row[0] for row in f]
print(action_list)
# Out:
# ['close', 'drink', 'find', 'grab', 'look_at', 'open', 'point_at', 'put_on', 'put_in', 'read', 'run', 'sit', 'stand_up', 'switch_off', 'switch_on', 'touch', 'turn_to', 'walk', 'watch', 'walk_to_wards', 'walk_for_ward', 'turn_left', 'turn_right']

# %% [markdown]
# Object List

# %%
s, graph = comm.environment_graph()
nodes = graph['nodes']

object_list = [n.get('class_name') for n in nodes]
#notExecutable_object = {'coffeemaker', 'coffeepot', 'cpuscreen', 'tablelamp', 'lime', 'oventray'}

object_list = sorted(list(set(object_list)))
print(object_list)
# Out:
# ['apple', 'bananas', 'barsoap', 'bathroom', 'bathroomcabinet', 'bathroomcounter', 'bathtub', 'bed', 'bedroom', 'bellpepper', 'bench', 'book', 'bookshelf', 'box', 'breadslice', 'cabinet', 'candle', 'candybar', 'ceiling', 'ceilinglamp', 'cellphone', 'cereal', 'chair', 'chips', 'chocolatesyrup', 'clock', 'closet', 'closetdrawer', 'clothespants', 'clothespile', 'clothesshirt', 'coffeemaker', 'coffeepot', 'coffeetable', 'computer', 'condimentbottle', 'condimentshaker', 'cpuscreen', 'crackers', 'creamybuns', 'cupcake', 'curtains', 'cutleryfork', 'cutleryknife', 'deodorant', 'desk', 'dishbowl', 'dishwashingliquid', 'door', 'doorjamb', 'facecream', 'faucet', 'floor', 'folder', 'fridge', 'fryingpan', 'garbagecan', 'hairproduct', 'hanger', 'keyboard', 'kitchen', 'kitchencabinet', 'kitchencounter', 'kitchencounterdrawer', 'kitchentable', 'lightswitch', 'lime', 'livingroom', 'microwave', 'mouse', 'mousemat', 'mug', 'nightstand', 'orchid', 'oventray', 'painkillers', 'paper', 'peach', 'perfume', 'photoframe', 'pie', 'pillow', 'plate', 'plum', 'powersocket', 'radio', 'remotecontrol', 'rug', 'salmon', 'sink', 'slippers', 'sofa', 'stall', 'stove', 'stovefan', 'tablelamp', 'toaster', 'toilet', 'toothbrush', 'toothpaste', 'towel', 'towelrack', 'tv', 'tvstand', 'wall', 'walllamp', 'wallphone', 'wallpictureframe', 'wallshelf', 'washingmachine', 'washingsponge', 'waterglass', 'whippedcream', 'window', 'wineglass']

# %%
import glob

from numpy import append

script_object_list = set()

files = glob.glob("executable/*.txt")
for file in files:
    with open(file, 'r') as f:
        file_data = f.readlines()[4:]

        for line in file_data:
            row = line.split()
            if len(row)==3:
                script_object_list.add(str(row[1]).replace("<", "").replace(">",""))
            elif len(row)==5:
                script_object_list.add(str(row[3]).replace("<", "").replace(">",""))

script_object_list = sorted(list(script_object_list))
print(script_object_list)
# Out:
# ['bathroom', 'bedroom', 'bowl', 'cd_player', 'chair', 'coffee_cup', 'coffee_table', 'computer', 'controller', 'couch', 'cup', 'desk', 'dining_room', 'faucet', 'filing_cabinet', 'food_food', 'freezer', 'home_office', 'keyboard', 'kitchen_cabinet', 'kitchen_counter', 'light', 'microwave', 'mouse', 'novel', 'oven', 'phone', 'plate', 'remote_control', 'shower', 'sink', 'stereo', 'table', 'television', 'toilet', 'tooth_paste', 'toothbrush', 'water_glass']

# %%
import json

json_open = open('class_name_equivalence_new.json', 'r')
object_name_equivalence = json.load(json_open)

# virtualhomeで定義された object_list中の同義語一覧
equivalence_object = [k for obj in object_list for k, v in object_name_equivalence.items() if obj in str(v).replace("_","")]
equivalence_object = sorted(list(set(equivalence_object)))
print(sorted(equivalence_object))
# Out:
# ['after_shave', 'alarm_clock', 'basket_for_clothes', 'bathroom_cabinet', 'bathroom_counter', 'bowl', 'carpet', 'cd_player', 'check', 'cleaning_bottle', 'cleaning_solution', 'cloth_napkin', 'coffe_maker', 'coffee_cup', 'coffee_pot', 'coffee_table', 'controller', 'couch', 'cup', 'cupboard', 'curtain', 'detergent', 'dining_room', 'dish_soap', 'document', 'drawing', 'dresser', 'drinking_glass', 'entrance_hall', 'face_soap', 'facial_cleanser', 'filing_cabinet', 'food_apple', 'food_bread', 'food_cereal', 'food_dessert', 'food_fish', 'food_food', 'food_fruit', 'food_lime', 'food_oatmeal', 'food_salt', 'food_snack', 'food_sugar', 'fork', 'freezer', 'garbage_can', 'glass', 'groceries', 'home_office', 'kitchen_cabinet', 'kitchen_counter', 'knife', 'light', 'lighting', 'living_room', 'love_seat', 'mat', 'mousepad', 'mug', 'napkin', 'notes', 'novel', 'oil', 'oven', 'painting', 'paper_towel', 'phone', 'pot', 'printing_paper', 'receipt', 'remote_control', 'sauce', 'sauce_pan', 'shampoo', 'shoes', 'shower', 'soap', 'sponge', 'stereo', 'table', 'telephone', 'television', 'textbook', 'toilet_paper', 'tooth_paste', 'towel_rack', 'trashcan', 'tray', 'wall_clock', 'water_glass', 'wine_glass']

# %% [markdown]
# Room List

# %%
room_list = [n.get("class_name") for n in nodes if n.get("category") == "Rooms"]
print(room_list)
# Out:
# ['bathroom', 'bedroom', 'kitchen', 'livingroom']

# %%
bathroom_id = 0
bedroom_id = 0
kitchen_id = 0
livingroom_id = 0

for n in nodes:
    if n.get("class_name") in room_list:
        if n.get("class_name")=="bathroom":
            bathroom_id = n.get("id")
            
        elif n.get("class_name")=="bedroom":
            bedroom_id = n.get("id")
            
        elif n.get("class_name")=="kitchen":
            kitchen_id = n.get("id")
            
        elif n.get("class_name")=="livingroom":
            livingroom_id = n.get("id")

bathroom_objects = []
bedroom_objects = []
kitchen_objects = []
livingroom_objects = []

edges = graph['edges']

for e in edges:
    if e.get("to_id") == bathroom_id and e.get("relation_type") == "INSIDE":
        bathroom_objects.append([n.get("class_name") for n in nodes if n.get("id") == e.get("from_id")][0])
        
    elif e.get("to_id") == bedroom_id and e.get("relation_type") == "INSIDE":
        bedroom_objects.append([n.get("class_name") for n in nodes if n.get("id") == e.get("from_id")][0])
    
    elif e.get("to_id") == kitchen_id and e.get("relation_type") == "INSIDE":
        kitchen_objects.append([n.get("class_name") for n in nodes if n.get("id") == e.get("from_id")][0])
    
    elif e.get("to_id") == livingroom_id and e.get("relation_type") == "INSIDE":
        livingroom_objects.append([n.get("class_name") for n in nodes if n.get("id") == e.get("from_id")][0])
        
bathroom_objects = sorted(list(set(bathroom_objects)))
bedroom_objects = sorted(list(set(bedroom_objects)))
kitchen_objects = sorted(list(set(kitchen_objects)))
livingroom_objects = sorted(list(set(livingroom_objects)))

room_dict = {"bathroom":bathroom_objects, "bedroom":bedroom_objects, "kitchen":kitchen_objects, "livingroom":livingroom_objects}

print('bathroom : ' + str(bathroom_objects))
print('bedroom : ' + str(bedroom_objects))
print('kitchen : ' + str(kitchen_objects))
print('livingroom : ' + str(livingroom_objects))
# Out:
# bathroom : ['barsoap', 'bathroomcabinet', 'bathroomcounter', 'bathtub', 'candle', 'ceiling', 'ceilinglamp', 'curtains', 'deodorant', 'door', 'doorjamb', 'facecream', 'faucet', 'floor', 'hairproduct', 'lightswitch', 'painkillers', 'perfume', 'plate', 'rug', 'stall', 'toilet', 'toothbrush', 'toothpaste', 'towel', 'towelrack', 'wall', 'walllamp', 'wallshelf', 'washingmachine', 'waterglass', 'window']
# bedroom : ['bed', 'book', 'bookshelf', 'box', 'candle', 'ceiling', 'ceilinglamp', 'cellphone', 'chair', 'closet', 'closetdrawer', 'clothespants', 'clothespile', 'clothesshirt', 'coffeetable', 'computer', 'cpuscreen', 'cupcake', 'curtains', 'desk', 'doorjamb', 'floor', 'folder', 'garbagecan', 'hanger', 'keyboard', 'lightswitch', 'mouse', 'mousemat', 'mug', 'nightstand', 'orchid', 'photoframe', 'pillow', 'plate', 'radio', 'rug', 'slippers', 'tablelamp', 'wall', 'wallpictureframe', 'window', 'wineglass']
# kitchen : ['bananas', 'bellpepper', 'bench', 'book', 'bookshelf', 'box', 'breadslice', 'candybar', 'ceiling', 'ceilinglamp', 'cereal', 'chips', 'chocolatesyrup', 'clock', 'clothespile', 'coffeemaker', 'coffeepot', 'condimentbottle', 'condimentshaker', 'crackers', 'creamybuns', 'cutleryfork', 'cutleryknife', 'dishbowl', 'dishwashingliquid', 'door', 'faucet', 'floor', 'fridge', 'fryingpan', 'kitchencabinet', 'kitchencounter', 'kitchencounterdrawer', 'kitchentable', 'lightswitch', 'microwave', 'orchid', 'oventray', 'paper', 'photoframe', 'pie', 'plate', 'powersocket', 'rug', 'salmon', 'sink', 'stove', 'stovefan', 'toaster', 'tv', 'tvstand', 'wall', 'wallphone', 'wallpictureframe', 'wallshelf', 'washingsponge', 'waterglass', 'whippedcream', 'wineglass']
# livingroom : ['apple', 'bananas', 'book', 'bookshelf', 'box', 'cabinet', 'ceiling', 'ceilinglamp', 'cellphone', 'chair', 'closet', 'closetdrawer', 'clothespants', 'clothespile', 'clothesshirt', 'coffeetable', 'computer', 'cpuscreen', 'curtains', 'desk', 'dishbowl', 'doorjamb', 'floor', 'folder', 'hanger', 'keyboard', 'lightswitch', 'lime', 'mouse', 'mousemat', 'mug', 'paper', 'peach', 'photoframe', 'pillow', 'plum', 'powersocket', 'remotecontrol', 'rug', 'sofa', 'tv', 'tvstand', 'wall', 'walllamp', 'wallpictureframe', 'window']

# %% [markdown]
# Word Net

# %%
from nltk.corpus import wordnet as wn

def get_synonyms(word):
    synonyms = set()

    for word in wn.synsets(word)[:5]:
        synonyms.add(str(word.name()).split('.')[0])

    return(synonyms)

# %% [markdown]
# Word2Vec

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')
# Out:
# 2023-01-15 18:22:03,894 : INFO : loading projection weights from C:\Users\j-aoyama/gensim-data\word2vec-google-news-300\word2vec-google-news-300.gz
# 2023-01-15 18:22:28,280 : INFO : KeyedVectors lifecycle event {'msg': 'loaded (3000000, 300) matrix of type float32 from C:\\Users\\j-aoyama/gensim-data\\word2vec-google-news-300\\word2vec-google-news-300.gz', 'binary': True, 'encoding': 'utf8', 'datetime': '2023-01-15T18:22:28.280401', 'gensim': '4.2.0', 'python': '3.8.3 (default, Jul  2 2020, 17:30:36) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22000-SP0', 'event': 'load_word2vec_format'}

# %%
def get_similar_object(word):
    point = 0
    similar_object = ""

    for object in object_list:

        try:
            if wv.similarity(word, object) > point:
                point = wv.similarity(word, object)
                similar_object = object

        except KeyError:
            pass
    
    if point > 0.5:
        return similar_object

# %% [markdown]
# Spacy

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# Transformer Pipeline

# %%
from transformers import pipeline
model = pipeline("fill-mask")

def fill_mask(word, num, text): #word <- 空欄にする単語     num <- wordの対象が複数ある時に対象とする場所を示す     text <- sentence
    doc = nlp(text)
    mask_text = ""
    count = 0
    for token in doc:
        if token.text == word:
            if num == count:
                mask_text += "{} "
            else:
                mask_text += token.text + " "

            count += 1   
        else:
            mask_text += token.text + " "
    #print(mask_text)
    
    inputs = [mask_text.format(model.tokenizer.mask_token)]
    #print(inputs)
    res = model(inputs, top_k=5)
    return [str(r["token_str"]).replace(" ", "") for r in res]

fill_mask("watch", 0, "I turn on the tv and sit in the sofa. I watch the tv.")
# Out:
# No model was supplied, defaulted to distilroberta-base and revision ec58a5b (https://huggingface.co/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ['watch', 'mute', 'hate', 'ignore', 'turn']

# %% [markdown]
# Convert to Present tense

# %%
def present_tense(text): # 動詞の活用形を現在形に直して返す
    for token in nlp(str(text).replace("_"," ")):
        if token.pos_== 'VERB':
            text = str(text).replace(token.text, token.lemma_)
    return text

# %% [markdown]
# Extract Action and Object

# %%
def decision_action_object(verb, pharasal_verb, object, sentence, num):

    decision_action = None
    decision_object = []

    # 動詞の決定
    if pharasal_verb:
        if present_tense(pharasal_verb) in action_list: # 句動詞がアクションリストに存在するか
            decision_action = str(present_tense(pharasal_verb))

        elif get_synonyms(present_tense(pharasal_verb)) & set(action_list): # 句動詞の同義語（WordNetで検索）がアクションリストに存在するか
            mached_list = list(get_synonyms(present_tense(pharasal_verb)) & set(action_list))

            if len(mached_list)==1:
                decision_action = mached_list[0]
            #else:
                #類似度の高いほう

    if decision_action is None:
        if present_tense(verb) in action_list: # 動詞がアクションリストに存在するか
            decision_action = present_tense(verb)

        elif get_synonyms(present_tense(verb)) & set(action_list): # 動詞の同義語（WordNetで検索）がアクションリストに存在するか
            mached_list = list(get_synonyms(present_tense(verb)) & set(action_list))

            if len(mached_list)==1:
                decision_action = mached_list[0]
            #else:
                #類似度の高いほう

        else:
            candidate_action = fill_mask(verb, num, sentence) # 文章中の動詞を空欄にして空欄部分に入りそうな動詞の候補を取得
            #print(candidate_action)
            for action in candidate_action: 
                action = present_tense(action)
                if action in action_list: # 候補中の動詞がアクションリストに存在すれば決定する
                    decision_action = action
                    break
                elif pharasal_verb: # 句動詞がある場合 候補中の動詞+前置詞 がアクションリストに存在するか
                    action = action + "_" + str(pharasal_verb).rsplit("_")[1]
                    if action in action_list:
                        decision_action = action
                        break
                #<- 複数存在する場合にどうするか？　オブジェクトのプロパティから実行できるか？　部屋の場合はWalkにしてしまうのか？

            #if decision_action is None: # 見つからなかったときに類似度で出すか？
                #decision_action = get_similar_action(verb)

    for obj in object:

        if obj in object_list: # オブジェクトがオブジェクトリストに存在するか
            decision_object.append(obj)

        elif obj in equivalence_object: # オブジェクトがVirtualhomeが定義しているオブジェクトリスト中の同義語一覧に存在する場合
            decision_object.append(list(set(object_name_equivalence.get(obj)) & set(object_list))[0]) # オブジェクトのVirtualhomeで定義された同義語とオブジェクトリストの共通集合から取得

        # "_" が文字列に含まれている場合
        elif "_" in str(obj): 
            obj = str(obj).replace("_","")  # "_" を外して上記と同じことをする
            if obj in object_list:
                decision_object.append(obj)

            elif obj in equivalence_object:
                decision_object.append(list(set(object_name_equivalence.get(obj)) & set(object_list))[0])

        elif set(get_synonyms(obj)) & set(object_list):
            mached_list = list(get_synonyms(obj) & set(object_list))

            if len(mached_list)==1:
                decision_object.append(mached_list[0])

            #else:
                #類似度の高いほう

        elif set(get_synonyms(obj)) & set(equivalence_object):
            mached_list = list(get_synonyms(obj) & set(equivalence_object))
            #print(mached_list)

            if len(mached_list)==1:
                decision_object.append(list(set(object_name_equivalence.get(mached_list[0])) & set(object_list))[0])

            #else:
                #類似度の高いほう

        elif get_similar_object(obj):
            decision_object.append(get_similar_object(obj))
    
    if "" in decision_object:
        decision_object.remove("")
    
    return decision_action, decision_object

# %% [markdown]
# Morphological analysis

# %%
def morphological_analysis(text):
    sentence_list = []
    sentence = ""

    for i, token in enumerate(text):

        if token.text==".":
            sentence = sentence.rstrip() + "."
            sentence_list.append(nlp(sentence))
            sentence = ""
        elif len(text)-1 == i:
            sentence += str(token.text).lower() + "."
            sentence_list.append(nlp(sentence))
        elif sentence == "" and token.tag_ != "PRP":#token.pos_ == "VERB"
            sentence += "I " + str(token.text).lower() + " "
        elif token.tag_ == "PRP":
            sentence += token.text + " "
        else:
            sentence += str(token.text).lower() + " "    

    #print(sentence_list)
    doc = ""
    for sentence in sentence_list:
        doc += str(sentence) + " "

    pair_dict_list = []
    for subActivity_doc in sentence_list:
        verb = None     #動詞
        prep = None     #前置詞修飾詞
        prt = None      #句動詞助詞
        comp = None     #補語
        object = []     #目的語
        compound = None #複合修飾詞
        pharasal_verb = None    #句動詞
        #adverb = None  #副詞

        for token in subActivity_doc:
            #print(token.text, token.tag_, token.pos_, token.head.text, token.dep_)

            if (token.dep_ == "ROOT" or token.dep_ == "conj" or token.dep_ == "dep" or token.dep_ == "advcl" or token.dep_ == "ccomp" or token.dep_ == "xcomp" or token.dep_ == "pcomp") and token.pos_ == "VERB": #token.pos_ == "VERB": 
                if verb or pharasal_verb:
                    # 辞書形式でアクションとオブジェクトのペアを追加
                    pair_dict = {}
                    if pharasal_verb:
                        pair_dict.setdefault("action", pharasal_verb)
                        pharasal_verb = None
                    else:
                        pair_dict.setdefault("action", verb)

                    object =  [obj for obj in object]
                    pair_dict.setdefault("object", object)
                    #pair_dict.setdefault("sentence", doc)
                    pair_dict_list.append(pair_dict)
                    # 空にする
                    verb = None
                    object = []

                verb = token.text

            elif token.dep_ == "dobj" and token.head.text == verb or token.dep_ == "pobj" and (token.head.text == prep or token.head.text == prt):
                if token.text == "it":
                    if pair_dict_list:
                        if pair_dict_list[-1].get("object"):
                            object.append(pair_dict_list[-1].get("object")[-1])
                elif compound:#<- 
                    object.append(compound + "_" + token.text)
                    compound = None
                else:
                    object.append(token.text)

            elif token.dep_ == "prt" and token.head.text == verb:
                prt = token.text
                if not pharasal_verb:
                    pharasal_verb = verb + "_" + prt

            elif token.dep_ == "prep" and token.head.text == verb:
                prep = token.text
                if not pharasal_verb:
                    pharasal_verb = verb + "_" + prep #改善
            
            elif token.dep_ == "conj" and token.pos_ == "NOUN":
                if compound:#<- 
                    object .append(compound + "_" + token.text)
                    compound = None
                else:
                    object.append(token.text)

            elif token.dep_ == "compound":
                compound = token.text

            elif token.dep_ == "punct" and token.text == ".":
                # 辞書形式でアクションとオブジェクトのペアを追加
                pair_dict = {}
                if pharasal_verb:
                    pair_dict.setdefault("action", pharasal_verb)
                    pharasal_verb = None
                else:
                    pair_dict.setdefault("action", verb)

                object =  [obj for obj in object]   
                pair_dict.setdefault("object", object)
                #pair_dict.setdefault("sentence", doc)
                pair_dict_list.append(pair_dict)

    #print(pair_dict_list)
    #print(doc)
    return pair_dict_list, doc

# %%
# オブジェクトを対象としないアクション
noObjAction = ["stand_up","turn_left","turn_right"]

# 2つのオブジェクトを対象とするアクション
twoObjAction = ["put_in", "put_back"]

# %%
find_object = []
grab_object = []

SITTING = False

# %%
def reset_action(action_script):
    script = []
    for action in action_script:
        action[0] = str(action[0]).replace("_","")
        if len(action)==1:
            script.append(f"<char0> [{action[0]}]")
        elif len(action)==2:
            script.append(f"<char0> [{action[0]}] <{action[1]}> (1)")
        elif len(action)==3:
            script.append(f"<char0> [{action[0]}] <{action[1]}> (1) <{action[2]}> (1)")
    
    comm.reset(0)
    comm.add_character('Chars/male1', initial_room='bathroom')
    success, graph = comm.environment_graph()
    comm.render_script(script=script, find_solution=True, skip_execution=False, recording=True, camera_mode=['AUTO'])

# %%
def execution_confirmation(s):
    s = str(s).replace("_","")
    script = []
    script.append(s)
    success, graph = comm.environment_graph()
    a, b = comm.render_script(script=script, find_solution=True, skip_execution=False, recording=True, camera_mode=['AUTO'])
    return a

# %%
import math
def calc_distance(a, b):
    x = abs(a[0] - b[0])
    z = abs(a[2] - b[2])
    y = math.sqrt(x*x + z*z)
    
    return y

# %%
def search_nearest_object(object_name):
    success, graph = comm.environment_graph()
    character = [n for n in graph["nodes"] if n.get("class_name")=="character"][0]
    chara_position = character.get("obj_transform").get("position")
    
    objects = [n for n in graph["nodes"] if n.get("class_name") == object_name]

    nearest_object_id = 0
    distance = 100
    
    for o in objects:
        object_position = o.get("obj_transform").get("position")
        if calc_distance(chara_position, object_position) < distance:
            distance = calc_distance(chara_position, object_position)
            nearest_object_id = o.get("id")
    
    return nearest_object_id, distance

# %%
def add_standup(action_script):
    global SITTING
    
    if SITTING == True:
        if execution_confirmation('<char0> [standup]') == True:
            action_script.append(["stand_up"])
            SITTING = False
        else:
            reset_action(action_script)
            
    return action_script

# %%
def add_walk_run(action_script, action, object, distance):
    
    if action_script and object in room_list:
    
        if action_script[-1][0] == "walk" or action_script[-1][0] == "run":
            
            if action_script[-1][1] in room_list:
                action_script = action_script[:-1]
                reset_action(action_script)
    
    if distance > 1:
        
        if execution_confirmation(f'<char0> [{action}] <{object}> (1)') == True:
            action_script.append([action, object])
        else:
            reset_action(action_script)
    
    return action_script

# %%
def add_find(action_script, object):
    if object not in find_object:
        
        if execution_confirmation(f'<char0> [find] <{object}> (1)') == True:
            action_script.append(["find", object])
            find_object.append(object)
        else:
            reset_action(action_script)
        
    return action_script

# %%
def add_grab(action_script, object):
    
    success, graph = comm.environment_graph()
    object_id, distance = search_nearest_object(object)
    properties = [n.get("properties") for n in graph["nodes"] if n.get("id") == object_id][0]
    
    if ("GRABBABLE" in properties) and (object not in grab_object) and ( len(grab_object) < 2 ):
        
        if execution_confirmation(f'<char0> [grab] <{object}> (1)') == True:
            action_script.append(["grab", object])
            grab_object.append(object)
        else:
            reset_action(action_script)
    
    return action_script

# %%
def add_open(action_script, object):
    
    success, graph = comm.environment_graph()
    object_id, distance = search_nearest_object(object)
    properties = [n.get("properties") for n in graph["nodes"] if n.get("id") == object_id][0]
    states = [n.get("states") for n in graph["nodes"] if n.get("id") == object_id][0]
    
    if ("CAN_OPEN" in properties) and ("CLOSED" in states) and ( len(grab_object) < 2 ):
        
        if execution_confirmation(f'<char0> [open] <{object}> (1)') == True:
            action_script.append(["open", object])
        else:
            reset_action(action_script)
            
    return action_script

# %% [markdown]
# Get Current Location

# %%
def current_location():
    success, graph = comm.environment_graph()
    character = [n for n in graph["nodes"] if n.get("class_name")=="character"][0]
    
    room_id = [e.get("to_id") for e in graph["edges"] if character.get("id") == e.get("from_id") and e.get("relation_type") == "INSIDE"][0]
    room_name = ""
    
    if room_id == bathroom_id:
        room_name = "bathroom"
    
    elif room_id == bedroom_id:
        room_name = "bedroom"
    
    elif room_id == kitchen_id:
        room_name = "kitchen"
        
    elif room_id == livingroom_id:
        room_name = "livingroom"
    
    return room_name

# %% [markdown]
# Add Action

# %%
def add_action(action_script, action, object):
    success, graph = comm.environment_graph()
    
    global SITTING
    object_id = 0
    distance = 100
    properties = []
    states = []
    
    if object:
        object_id, distance = search_nearest_object(object[0])
        properties = [n.get("properties") for n in graph["nodes"] if n.get("id") == object_id][0]
        states = [n.get("states") for n in graph["nodes"] if n.get("id") == object_id][0] 
    
    if action in noObjAction:
        
        if action == "stand_up":
            action_script = add_standup(action_script)
            
        else:
            action_script = add_standup(action_script)
            
            if execution_confirmation(f'<char0> [{action}]') == True:
                action_script.append([action])
            else:
                reset_action(action_script)
            
    
    elif action=="walk" or action=="run":
        action_script = add_standup(action_script)
        action_script = add_walk_run(action_script, action, object[0], distance)

        
    elif action=="find":
        
        if distance > 1:
            action_script = add_standup(action_script)
            action_script = add_walk_run(action_script, "walk", object[0], distance)
            
        action_script = add_find(action_script, object[0])
    
    
    elif action == "watch":
        
        objects_id = [n.get("id") for n in graph["nodes"] if n.get("class_name") == object[0]]
        room_name = ""
            
        for object_id in objects_id:  
            room_id = [e.get("to_id") for e in graph["edges"] if object_id == e.get("from_id") and e.get("relation_type") == "INSIDE"][0]
            if room_id == bathroom_id and current_location() == "bathroom":
                room_name = "bathroom"
                break
    
            elif room_id == bedroom_id and current_location() == "bedroom":
                room_name = "bedroom"
                break
    
            elif room_id == kitchen_id and current_location() == "kitchen":
                room_name = "kitchen"
                break
        
            elif room_id == livingroom_id and current_location() == "livingroom":
                room_name = "livingroom"
                break
                    
        if "HAS_SWITCH" in properties:
                
            if "OFF" in states:
                action_script = add_standup(action_script)
                action_script = add_walk_run(action_script, "walk", object[0], distance)
                action_script = add_find(action_script, object[0])
                    
                if execution_confirmation(f'<char0> [switchon] <{object[0]}> (1)') == True:
                    action_script.append(["switchon", object[0]])
                else:
                    reset_action(action_script)
            
            elif room_name == "":
                action_script = add_standup(action_script)
                action_script = add_walk_run(action_script, "walk", object[0], distance)
                action_script = add_find(action_script, object[0])
                
            else:
                action_script = add_find(action_script, object[0])
                
        else:
            
            if room_name == "":
                action_script = add_standup(action_script)
                action_script = add_walk_run(action_script, "walk", object[0], distance)
                action_script = add_find(action_script, object[0])
                
            else:
                action_script = add_find(action_script, object[0])
                
                
        if execution_confirmation(f'<char0> [watch] <{object[0]}> (1)') == True:
            action_script.append(["watch", object[0]])
        else:
            reset_action(action_script)
            
            
    else:
        action_script = add_standup(action_script)
        action_script = add_walk_run(action_script, "walk", object[0], distance)
        action_script = add_find(action_script, object[0])
    
        if action == "sit":
            
            if "SITTABLE" in properties:
                if execution_confirmation(f'<char0> [sit] <{object[0]}> (1)') == True:
                    action_script.append(["sit", object[0]])
                    SITTING = True
                else:
                    reset_action(action_script)
            
            
        elif action == "grab":
            action_script = add_grab(action_script, object[0])

                
        elif action == "open":
            action_script = add_open(action_script, object[0])

                    
        elif action == "close":
    
            if ("CAN_OPEN" in properties) and ("OPEN" in states) and ( len(grab_object) < 2 ):
        
                if execution_confirmation(f'<char0> [close] <{object[0]}> (1)') == True:
                    action_script.append(["close", object[0]])
                else:
                    reset_action(action_script)

                    
        elif action == "put_on" and len(object) > 1:
            
            if len(grab_object) < 2:
                action_script = add_grab(action_script, object[0])
                
                object_id, distance = search_nearest_object(object[1])
                
                action_script = add_walk_run(action_script, "walk", object[1], distance)
                action_script = add_find(action_script, object[1])
                
                # VirtualHome での表記上，putback > puton となる．
                if execution_confirmation(f'<char0> [putback] <{object[0]}> (1) <{object[1]}> (1)') == True:
                    action_script.append(["putback", object[0], object[1]])
                    grab_object.remove(object[0])
                else:
                    reset_action(action_script)

            
        elif action == "put_in" and len(object) > 1:
            
            if len(grab_object) == 0:
                action_script = add_grab(action_script, object[0])
                
                object_id, distance = search_nearest_object(object[1])
                properties = [n.get("properties") for n in graph["nodes"] if n.get("id") == object_id][0]
        
                action_script = add_walk_run(action_script, "walk", object[1], distance)
                action_script = add_find(action_script, object[1])
                action_script = add_open(action_script, object[1])
        
                if "CONTAINERS" in properties:
        
                    if execution_confirmation(f'<char0> [putin] <{object[0]}> (1) <{object[1]}> (1)') == True:
                        action_script.append(["putin", object[0], object[1]])
                        grab_object.remove(object[0])
                    else:
                        reset_action(action_script)      
                

        elif action == "switch_on":
            
            if "HAS_SWITCH" in properties and  "OFF" in states:
                if execution_confirmation(f'<char0> [switchon] <{object[0]}> (1)') == True:
                    action_script.append(["switchon", object[0]])
                else:
                    reset_action(action_script)

                
        elif action == "switch_off":
            
            if "HAS_SWITCH" in properties and  "ON" in states:
                if execution_confirmation(f'<char0> [switchoff] <{object[0]}> (1)') == True:
                    action_script.append(["switchoff", object[0]])
                else:
                    reset_action(action_script)

                
        elif action == "drink":
            
            if "RECIPIENT" in properties and "POURABLE" in properties:
                
                if object[0] not in grab_object:
                    action_script = add_grab(action_script, object[0])
                    
                if execution_confirmation(f'<char0> [drink] <{object[0]}> (1)') == True:
                    action_script.append(["drink", object[0]])
                else:
                    reset_action(action_script)

                    
        elif action == "look_at":
            
            if execution_confirmation(f'<char0> [turnto] <{object[0]}> (1)') == True:
                action_script.append(["turnto", object[0]])
            else:
                reset_action(action_script)
                
            if execution_confirmation(f'<char0> [lookat] <{object[0]}> (1)') == True:
                action_script.append(["lookat", object[0]])
            else:
                reset_action(action_script)
            

        elif action == "read":
            
            if "READABLE" in properties:
                
                if object[0] not in grab_object:
                    action_script = add_grab(action_script, object[0])
                    
                if execution_confirmation(f'<char0> [read] <{object[0]}> (1)') == True:
                    action_script.append(["read", object[0]])
                else:
                    reset_action(action_script)
    
    return action_script

# %% [markdown]
# Generate Script

# %%
def generate_script(text):

    action_script = []

    #依存構造解析の情報を保存 
    row = morphological_analysis(nlp(text))
    text_info = row[0]
    sentence = row[1]
    verb_list = [str(info.get("action")).rsplit("_")[0] for info in text_info] # 動詞の一覧

    for num, info in enumerate(text_info):
        if "_" in str(info.get("action")): # 動詞+前置詞の場合 動詞と句動詞2パターンに分解
            verb = str(info.get("action")).rsplit("_")[0]
            pharasal_verb = str(info.get("action"))
        else:
            verb = str(info.get("action"))
            pharasal_verb = None
        
        if verb_list[:num+1].count("verb") > 1: # 同じ動詞が存在する場合に前から何番目か計算 <- fill_mask で空欄にする場所を知っておきたい
            row = decision_action_object(verb, pharasal_verb, info.get("object"), sentence, verb_list[:num+1].count("verb")-1)
        else:
            row = decision_action_object(verb, pharasal_verb, info.get("object"), sentence, 0)
        action = row[0]
        object = row[1]
        #print(action, object)

        # アクションとオブジェクト両方ある場合
        if action and object:
            
            # オブジェクトがある部屋をカウント
            count = 0
            for value in room_dict.values():
                if object[0] in value:
                    count += 1
                    
            # オブジェクトが部屋の場合
            if object[0] in room_list:
                if action=="walk" or action=="run" and current_location() != object[0]:
                    action_script = add_action(action_script, action, object)
                
            # オブジェクトがある部屋が複数ある
            elif count>1:
                
                object_in_current_room = False
                
                for key, value in room_dict.items():
                    # 現在いる部屋にオブジェクトが存在する場合
                    if object[0] in value and current_location() == key:
                        action_script = add_action(action_script, action, object)
                        object_in_current_room = True
                        break

                # 現在いる部屋にオブジェクトが存在しなかった場合、近いほうのオブジェクトを選択し、その部屋まで移動
                if object_in_current_room == False:
                    
                    nearest_object_id, distance = search_nearest_object(object[0])
                        
                    room_id = [e.get("to_id") for e in graph["edges"] if nearest_object_id == e.get("from_id") and e.get("relation_type") == "INSIDE"][0]
                    if room_id == bathroom_id:
                        action_script = add_action(action_script, "walk", ["bathroom"])
    
                    elif room_id == bedroom_id:
                        action_script = add_action(action_script, "walk", ["bedroom"])
    
                    elif room_id == kitchen_id:
                        action_script = add_action(action_script, "walk", ["kitchen"])
        
                    elif room_id == livingroom_id:
                        action_script = add_action(action_script, "walk", ["livingroom"])
                    
                    action_script = add_action(action_script, action, object)
                        
                    #または、関係なしにアクションスクリプトに追加
                                    
            else:
                #オブジェクトがバスルームにある
                if object[0] in bathroom_objects and current_location() != "bathroom":
                    action_script = add_action(action_script, "walk", ["bathroom"])

                #オブジェクトがベッドルームにある
                elif object[0] in bedroom_objects and current_location() != "bedroom":
                    action_script = add_action(action_script, "walk", ["bedroom"])

                #オブジェクトがダイニングルームにある
                elif object[0] in kitchen_objects and current_location() != "kitchen":
                    action_script = add_action(action_script, "walk", ["kitchen"])

                #オブジェクトがホームオフィスにある
                elif object[0] in livingroom_objects and current_location() != "livingroom":
                    action_script = add_action(action_script, "walk", ["livingroom"])

                action_script = add_action(action_script, action, object)
                
        
        # 引数を必要としないアクションの場合
        elif action in noObjAction:
            action_script = add_action(action_script, action, object)
              
    return action_script

# %%
comm.reset(0)
comm.add_character('Chars/male1', initial_room='bathroom')
success, graph = comm.environment_graph()

SITTING = False

activity_text = 'Walk to the entrance hall. Find the telephone. Grab the telephone.'
find_object = []
grab_object = []

script = generate_script(activity_text)
print(script)
# Out:
# [['walk', 'livingroom'], ['find', 'cellphone'], ['grab', 'cellphone']]

# %%
import datetime

def generate_script_file(label, description):
    comm.reset(0)
    comm.add_character('Chars/male1', initial_room='bathroom')
    success, graph = comm.environment_graph()

    global SITTING
    SITTING = False

    dt = datetime.datetime.today()
    fname = "output/" + str(dt.date()) + "_" + label + ".txt"

    f = open(fname, 'w')
    f.write(label + "\n")
    f.write(description + "\n\n\n")

    global find_object, grab_object
    find_object = [] 
    grab_object = []
    script = generate_script(description)

    for row in script:
        if len(row) == 1:
            f.write("[" + str(row[0]).upper() + "]\n")

        elif len(row) == 2:
            f.write("[" + str(row[0]).upper() + "] <" + str(row[1]) + "> (1)\n")

        else:
            f.write("[" + str(row[0]).upper() + "] <" + str(row[1]) + "> (1) <" + str(row[2]) + "> (1)\n")
            
    f.close()

# %%
# 行動全体のラベル名
label_title = "Put salmon in fridge"
# 行動の詳細な説明
action_description = "go to the kitchen and put salmon in fridge."

generate_script_file(label_title, action_description)

# %%
import glob

files = glob.glob("executable/*.txt")

accuracy_list = []
recall_list = []

action_accuracy_list = []
action_recall_list = []

object_accuracy_list = []
object_recall_list = []

error_files = []

mistake_objects = []

for file in files:
    comm.reset(0)
    comm.add_character('Chars/male1', initial_room='bathroom')
    success, graph = comm.environment_graph()

    global SITTING, find_object, grab_object
    SITTING = False
    find_object = []
    grab_object = [] 
    print(file)

    with open(file, 'r') as f:
        text = f.readlines()[1].strip("\n")
        print("入力文：" + text)

    with open(file, 'r') as f:
        correct_data = []
        correct_script = []
        file_data = f.readlines()[4:]

        for line in file_data:

            if len(line.split()) == 1:
                correct_data.append(str(line).strip("\n"))
                correct_script.append(correct_data)

            elif len(line.split()) == 3:
                correct_data = line.split()[:2]
                correct_script.append(correct_data)

            else:
                correct_data = line.split()[:2]
                correct_data.append(line.split()[3])
                correct_script.append(correct_data)

    try:
        script = generate_script(text)

        # データセット用の表記に置き換える
        for row in script:
            if len(row) > 1:
            
                if row[1] not in equivalence_object:
                    keys = [k for k, v in object_name_equivalence.items() if row[1] in v and k in script_object_list] #<- 評価用と実装用で分けて考える
                    keys = list(set(equivalence_object) & set(keys))

                    if len(keys) > 0:
                        row[1] = keys[0]
                
                if len(row) == 3:

                    if row[2] not in equivalence_object:
                        keys = [k for k, v in object_name_equivalence.items() if row[2] in v and k in script_object_list] #<- 評価用と実装用で分けて考える
                        keys = list(set(equivalence_object) & set(keys))

                        if len(keys) > 0:
                            row[2] = keys[0]
                            

        for i, row in enumerate(script):
            script[i][0] = "[" + str(row[0]).upper().replace("_", "") + "]"
            
            if len(row) > 1:
                script[i][1] = "<" + row[1] + ">"
                if len(row) == 3:
                    script[i][2] = "<" + row[2] + ">"

        print("出力アクション")
        print(script)
        print("正解アクション")
        print(correct_script)


        #システム出力アクション数
        output_action_num = len(script)
        #システム出力のオブジェクトの数
        output_object_num = 0
        #正解アクション数
        correct_num = len(correct_script)
        #正解オブジェクトの数
        correct_object_num = 0
        for row in correct_script:
            if len(row) > 1:
                correct_object_num += 1
        #システム出力中の正解アクション数
        output_correct_num = 0
        output_action_correct_num = 0
        output_object_correct_num = 0

        
        # 最後に正解した正解アクションスクリプト中の正解アクションの位置
        last_correct_index = -1

        # 出力アクションをリストの前から見ていき，正解アクションに照合する．
        # 正解時は，last_correct_index を更新する．
        # 照合するときは，last_correct_index の次の要素から照らし合わせる．つまり，順序を考慮したいため，正解したアクションより前のアクションは照合しない．

        # ここでは，アクションとオブジェクトのセットで照合
        for row in script:
            
            #次照合する位置
            index = last_correct_index + 1

            # 同じ要素数を持っていなければ不正解．
            if len(row) == len(correct_script[index]):

                if len(row) == 1:

                    # 出力アクションと最後に正解したアクション以降のアクションと順に照合
                    for i in range(index, len(correct_script)):

                        if row[0] == correct_script[i][0]:
                            output_correct_num += 1
                            last_correct_index = i
                            break

                # オブジェクト１つのアクション
                elif len(row) == 2:
                
                    for i in range(index, len(correct_script)):

                        if row[0] == correct_script[i][0] and row[1] == correct_script[i][1]:
                            output_correct_num += 1
                            last_correct_index = i
                            break

                # オブジェクトが２つのアクション
                else:

                    for i in range(index, len(correct_script)):

                        if row[0] == correct_script[i][0] and row[1] == correct_script[i][1] and row[2] == correct_script[i][2]:
                            output_correct_num += 1
                            last_correct_index = i
                            break

                #正解アクションスクリプトの最後の要素に達した場合 
                if len(correct_script)-1 == last_correct_index:
                    break


        # アクション（動作）のみの照合
        last_correct_index = -1
        for row in script:

            index = last_correct_index + 1
            
            for i in range(index, len(correct_script)):

                if row[0] == correct_script[i][0]:
                    output_action_correct_num += 1
                    last_correct_index = i
                    break
 
            if len(correct_script)-1 == last_correct_index:
                break


        # オブジェクトのみの照合，オブジェクト（引数）が２つのアクションの場合は，２つ正解の場合に正解とみなす．
        last_correct_index = -1

        for row in script:

            index = last_correct_index + 1

            if len(row) > 1:
                output_object_num += 1

                if len(row) == len(correct_script[index]):

                    if len(row) == 2:

                        for i in range(index, len(correct_script)):

                            if row[1] == correct_script[i][1]:
                                output_object_correct_num += 1
                                last_correct_index = i
                                break

                    else:

                        for i in range(index, len(correct_script)):

                            if row[1] == correct_script[i][1] and row[2] == correct_script[i][2]:
                                output_object_correct_num += 1
                                last_correct_index = i
                                break

            if len(correct_script)-1 == last_correct_index:
                break

        
        #適合率
        accuracy = output_correct_num/output_action_num
        accuracy_list.append(accuracy)

        action_accuracy = output_action_correct_num/output_action_num
        action_accuracy_list.append(action_accuracy)

        object_accuracy = output_object_correct_num/output_object_num
        object_accuracy_list.append(object_accuracy)

        #再現率
        recall = output_correct_num/correct_num
        recall_list.append(recall)

        action_recall = output_action_correct_num/correct_num
        action_recall_list.append(action_recall)

        object_recall = output_object_correct_num/correct_object_num
        object_recall_list.append(object_recall)

        print("適合率：" + "{:.3f}".format(accuracy))
        print("再現率：" + "{:.3f}".format(recall))
        print("適合率（アクション）：" + "{:.3f}".format(action_accuracy))
        print("再現率（アクション）：" + "{:.3f}".format(action_recall))
        print("適合率（オブジェクト）：" + "{:.3f}".format(object_accuracy))
        print("再現率（オブジェクト）：" + "{:.3f}".format(object_recall))
    
    
    except:
        print("Error")
        error_files.append(file)
        pass


print("平均　適合率：" + "{:.3f}".format(sum(accuracy_list)/len(accuracy_list)))
print("平均　再現率：" + "{:.3f}".format(sum(recall_list)/len(recall_list)))
print("平均　適合率（アクション）：" + "{:.3f}".format(sum(action_accuracy_list)/len(action_accuracy_list)))
print("平均　再現率（アクション）：" + "{:.3f}".format(sum(action_recall_list)/len(action_recall_list)))
print("平均　適合率（オブジェクト）：" + "{:.3f}".format(sum(object_accuracy_list)/len(object_accuracy_list)))
print("平均　再現率（オブジェクト）：" + "{:.3f}".format(sum(object_recall_list)/len(object_recall_list)))

def get_variance(l, ave):
    total = 0
    for n in l:
        total += (n-ave)*(n-ave)
    return total/len(l)

print("分散　適合率：" + "{:.3f}".format(get_variance(accuracy_list, sum(accuracy_list)/len(accuracy_list))))
print("分散　再現率：" + "{:.3f}".format(get_variance(recall_list, sum(recall_list)/len(recall_list))))
print("分散　適合率（アクション）：" + "{:.3f}".format(get_variance(action_accuracy_list, sum(action_accuracy_list)/len(action_accuracy_list))))
print("分散　再現率（アクション）：" + "{:.3f}".format(get_variance(action_recall_list, sum(action_recall_list)/len(action_recall_list))))
print("分散　適合率（オブジェクト）：" + "{:.3f}".format(get_variance(object_accuracy_list, sum(object_accuracy_list)/len(object_accuracy_list))))
print("分散　再現率（オブジェクト）：" + "{:.3f}".format(get_variance(object_recall_list, sum(object_recall_list)/len(object_recall_list))))

print("error files: " + str(error_files))
print("number of errors: " + str(len(error_files)))
# Out:
# executable\file1004_2.txt
# 入力文：walk to kitchen, walk to fridge, look at bags, grab groceries, put groceries in fridge.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>'], ['[WALK]', '<food_food>'], ['[WALK]', '<freezer>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<freezer>'], ['[FIND]', '<food_food>'], ['[GRAB]', '<food_food>'], ['[OPEN]', '<freezer>'], ['[PUTIN]', '<food_food>', '<freezer>']]
# 適合率：0.286
# 再現率：0.333
# 適合率（アクション）：0.571
# 再現率（アクション）：0.667
# 適合率（オブジェクト）：0.750
# 再現率（オブジェクト）：0.500
# executable\file1007_2.txt
# 入力文：walk to bathroom , run to toilet
# 出力アクション
# [['[WALK]', '<bathroom>'], ['[RUN]', '<toilet>']]
# 正解アクション
# [['[WALK]', '<bathroom>'], ['[RUN]', '<toilet>']]
# 適合率：1.000
# 再現率：1.000
# 適合率（アクション）：1.000
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file1057_1.txt
# 入力文：Go to the living room, sit on the couch, find the remote, switch on the TV and watch
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[STANDUP]'], ['[WALK]', '<remote_control>'], ['[FIND]', '<remote_control>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[FIND]', '<remote_control>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[TURNTO]', '<television>'], ['[WATCH]', '<television>']]
# 適合率：0.778
# 再現率：0.778
# 適合率（アクション）：0.778
# 再現率（アクション）：0.778
# 適合率（オブジェクト）：0.875
# 再現率（オブジェクト）：0.778
# executable\file1064_1.txt
# 入力文：Drink water
# 出力アクション
# []
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<water_glass>'], ['[FIND]', '<water_glass>'], ['[GRAB]', '<water_glass>'], ['[DRINK]', '<water_glass>']]
# Error
# executable\file1065_1.txt
# 入力文：I find the remote control, turn, and walk over to it. I pick up the remote control. I look at the television. I point the remote control at the television and use it.
# 出力アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[TURNTO]', '<television>'], ['[LOOKAT]', '<television>']]
# 正解アクション
# [['[FIND]', '<remote_control>'], ['[TURNTO]', '<remote_control>'], ['[LOOKAT]', '<remote_control>'], ['[TURNTO]', '<remote_control>'], ['[WALK]', '<remote_control>'], ['[GRAB]', '<remote_control>'], ['[FIND]', '<television>'], ['[TURNTO]', '<television>'], ['[LOOKAT]', '<television>'], ['[TURNTO]', '<television>'], ['[WATCH]', '<television>'], ['[POINTAT]', '<television>'], ['[SWITCHON]', '<television>']]
# 適合率：0.600
# 再現率：0.231
# 適合率（アクション）：0.800
# 再現率（アクション）：0.308
# 適合率（オブジェクト）：0.800
# 再現率（オブジェクト）：0.308
# executable\file1068_1.txt
# 入力文：walk to home office ,find computer ,switch on computer and work
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[WALK]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 適合率：0.800
# 再現率：1.000
# 適合率（アクション）：0.800
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file1073_1.txt
# 入力文：Walk to home office, turn on light, grab a book, sit in chair, start to read the book
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>'], ['[GRAB]', '<novel>'], ['[WALK]', '<chair>'], ['[FIND]', '<chair>'], ['[READ]', '<novel>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>'], ['[FIND]', '<novel>'], ['[GRAB]', '<novel>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[READ]', '<novel>']]
# 適合率：0.778
# 再現率：0.778
# 適合率（アクション）：0.778
# 再現率（アクション）：0.778
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.667
# executable\file1088_1.txt
# 入力文：I go to the book case, I select a book, I go back and sit down, then I read.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>']]
# 正解アクション
# [['[WALK]', '<filing_cabinet>'], ['[FIND]', '<novel>'], ['[GRAB]', '<novel>'], ['[WALK]', '<couch>'], ['[READ]', '<novel>']]
# 適合率：0.333
# 再現率：0.200
# 適合率（アクション）：0.667
# 再現率（アクション）：0.400
# 適合率（オブジェクト）：0.667
# 再現率（オブジェクト）：0.400
# executable\file113_1.txt
# 入力文：I find CD player. I turn on CD player. I press play.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<stereo>'], ['[FIND]', '<stereo>'], ['[SWITCHON]', '<stereo>']]
# 正解アクション
# [['[FIND]', '<cd_player>'], ['[SWITCHON]', '<cd_player>'], ['[TOUCH]', '<cd_player>']]
# 適合率：0.000
# 再現率：0.000
# 適合率（アクション）：0.500
# 再現率（アクション）：0.667
# 適合率（オブジェクト）：0.000
# 再現率（オブジェクト）：0.000
# executable\file119_1.txt
# 入力文：in my home i walk to the kitchen with some groceries and locate the fridge,then open the fridge put the groceries into the fridge and closed.
# 出力アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<freezer>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>'], ['[GRAB]', '<food_food>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[PUTIN]', '<food_food>', '<freezer>'], ['[CLOSE]', '<freezer>']]
# 適合率：0.750
# 再現率：0.375
# 適合率（アクション）：1.000
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：0.750
# 再現率（オブジェクト）：0.375
# executable\file122_2.txt
# 入力文：go to the living room,find the computer,took the chair and place the chair to in front of the computer,sat on the chair,switch on the computer,open the email,and compose a new mail
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[FIND]', '<chair>'], ['[GRAB]', '<chair>'], ['[WALK]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[TURNTO]', '<computer>'], ['[LOOKAT]', '<computer>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[SWITCHON]', '<computer>'], ['[TURNTO]', '<computer>'], ['[FIND]', '<mouse>'], ['[TURNTO]', '<mouse>'], ['[POINTAT]', '<mouse>']]
# 適合率：0.714
# 再現率：0.417
# 適合率（アクション）：0.714
# 再現率（アクション）：0.417
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.583
# executable\file124_1.txt
# 入力文：go to the living room,find the sofa,sat down in the sofa,take some relaxation.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 適合率：1.000
# 再現率：1.000
# 適合率（アクション）：1.000
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file137_1.txt
# 入力文：allow sofa to support weight in order to decrease gravity induced entropy
# 出力アクション
# []
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[WALK]', '<couch>'], ['[SIT]', '<couch>']]
# Error
# executable\file141_1.txt
# 入力文：Walk Into Kitchen. Open Refrigerator. Grab Food. Walk to Microwave. Insert food into microwave. Cook until warm.
# 出力アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<freezer>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[WALK]', '<microwave>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[FIND]', '<food_food>'], ['[CLOSE]', '<freezer>'], ['[WALK]', '<microwave>'], ['[SWITCHON]', '<microwave>'], ['[SWITCHOFF]', '<microwave>']]
# 適合率：0.800
# 再現率：0.500
# 適合率（アクション）：0.800
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.625
# executable\file144_1.txt
# 入力文：turn tv on, watch TV
# 出力アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[WATCH]', '<television>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[FIND]', '<remote_control>'], ['[TURNTO]', '<remote_control>'], ['[FIND]', '<television>'], ['[TURNTO]', '<television>'], ['[WATCH]', '<television>']]
# 適合率：0.400
# 再現率：0.222
# 適合率（アクション）：0.800
# 再現率（アクション）：0.444
# 適合率（オブジェクト）：0.750
# 再現率（オブジェクト）：0.333
# executable\file145_1.txt
# 入力文：I sit at my computer desk and open the browser.
# 出力アクション
# []
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<desk>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# Error
# executable\file150_2.txt
# 入力文：push any ligth button to turn it on, for example in the living room
# 出力アクション
# []
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>']]
# Error
# executable\file152_2.txt
# 入力文：take every item from groceries bag and put them in the fridge
# 出力アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<freezer>'], ['[FIND]', '<freezer>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>'], ['[GRAB]', '<food_food>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[PUTIN]', '<food_food>', '<freezer>']]
# 適合率：0.667
# 再現率：0.286
# 適合率（アクション）：1.000
# 再現率（アクション）：0.429
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.429
# executable\file153_2.txt
# 入力文：turn computer on, open application to work with
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 適合率：0.750
# 再現率：0.750
# 適合率（アクション）：1.000
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：0.750
# 再現率（オブジェクト）：0.750
# executable\file155_2.txt
# 入力文：Put groceries into the fridge
# 出力アクション
# []
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<freezer>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[FIND]', '<food_food>'], ['[GRAB]', '<food_food>'], ['[PUTIN]', '<food_food>', '<freezer>'], ['[CLOSE]', '<freezer>']]
# Error
# executable\file156_1.txt
# 入力文：Drink water from a cup
# 出力アクション
# [['[WALK]', '<cup>'], ['[FIND]', '<cup>'], ['[GRAB]', '<cup>'], ['[DRINK]', '<cup>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<cup>'], ['[FIND]', '<cup>'], ['[GRAB]', '<cup>'], ['[FIND]', '<faucet>'], ['[WALK]', '<sink>'], ['[PUTBACK]', '<cup>', '<sink>'], ['[SWITCHON]', '<faucet>'], ['[SWITCHOFF]', '<faucet>'], ['[GRAB]', '<cup>'], ['[DRINK]', '<cup>']]
# 適合率：1.000
# 再現率：0.364
# 適合率（アクション）：1.000
# 再現率（アクション）：0.364
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.364
# executable\file158_1.txt
# 入力文：The person will stand , walk to the bathroom, and this case look at the toilet in the bathroom as no other action was requested
# 出力アクション
# [['[WALK]', '<bathroom>'], ['[WALK]', '<toilet>'], ['[FIND]', '<toilet>'], ['[TURNTO]', '<toilet>'], ['[LOOKAT]', '<toilet>']]
# 正解アクション
# [['[STANDUP]'], ['[WALK]', '<bathroom>'], ['[WALK]', '<toilet>'], ['[FIND]', '<toilet>'], ['[TURNTO]', '<toilet>'], ['[LOOKAT]', '<toilet>']]
# 適合率：0.000
# 再現率：0.000
# 適合率（アクション）：1.000
# 再現率（アクション）：0.833
# 適合率（オブジェクト）：0.000
# 再現率（オブジェクト）：0.000
# executable\file160_1.txt
# 入力文：Go to the living room, find the switches (buttons or controllers) for light 1 and light 2 and switch on both the lights one by one.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>'], ['[FIND]', '<light>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<controller>'], ['[FIND]', '<controller>'], ['[FIND]', '<controller>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>']]
# 適合率：0.667
# 再現率：0.250
# 適合率（アクション）：1.000
# 再現率（アクション）：0.375
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.375
# executable\file162_1.txt
# 入力文：Lift the remote and change the channel
# 出力アクション
# [['[WALK]', '<home_office>'], ['[FIND]', '<remote_control>'], ['[GRAB]', '<remote_control>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[FIND]', '<remote_control>'], ['[GRAB]', '<remote_control>'], ['[TURNTO]', '<television>'], ['[WATCH]', '<television>']]
# 適合率：1.000
# 再現率：0.375
# 適合率（アクション）：1.000
# 再現率（アクション）：0.375
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.375
# executable\file163_1.txt
# 入力文：Take a book, open it and read it
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>'], ['[WALK]', '<novel>'], ['[GRAB]', '<novel>'], ['[READ]', '<novel>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>'], ['[GRAB]', '<novel>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[READ]', '<novel>']]
# 適合率：0.667
# 再現率：0.571
# 適合率（アクション）：0.833
# 再現率（アクション）：0.714
# 適合率（オブジェクト）：0.800
# 再現率（オブジェクト）：0.571
# executable\file169_2.txt
# 入力文：Go to the office an open the computer at the desk
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<desk>']]
# 正解アクション
# [['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[FIND]', '<keyboard>'], ['[GRAB]', '<keyboard>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 適合率：0.000
# 再現率：0.000
# 適合率（アクション）：0.000
# 再現率（アクション）：0.000
# 適合率（オブジェクト）：0.000
# 再現率（オブジェクト）：0.000
# executable\file16_2.txt
# 入力文：I walk to the living room and pick up a book from the coffee table. I find my favorite chair.  I sit in the armchair and open the book.  I read.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<chair>'], ['[FIND]', '<chair>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[STANDUP]'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>'], ['[WALK]', '<coffee_table>'], ['[GRAB]', '<novel>'], ['[WALK]', '<chair>'], ['[SIT]', '<chair>'], ['[READ]', '<novel>']]
# 適合率：0.222
# 再現率：0.250
# 適合率（アクション）：0.556
# 再現率（アクション）：0.625
# 適合率（オブジェクト）：0.571
# 再現率（オブジェクト）：0.500
# executable\file170_1.txt
# 入力文：find the TV remote, Use the remote to turn on the TV, sit on the couch, watch te
# 出力アクション
# [['[WALK]', '<home_office>'], ['[FIND]', '<remote_control>'], ['[GRAB]', '<remote_control>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[FIND]', '<remote_control>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[FIND]', '<television>'], ['[TURNTO]', '<television>'], ['[LOOKAT]', '<television>']]
# 適合率：0.556
# 再現率：0.625
# 適合率（アクション）：0.556
# 再現率（アクション）：0.625
# 適合率（オブジェクト）：0.444
# 再現率（オブジェクト）：0.500
# executable\file17_1.txt
# 入力文：walk to kitchen, walk to table, grab water glass and drink water
# 出力アクション
# [['[WALK]', '<bathroom>'], ['[WALK]', '<cup>'], ['[FIND]', '<cup>'], ['[GRAB]', '<cup>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<table>'], ['[FIND]', '<water_glass>'], ['[GRAB]', '<water_glass>'], ['[DRINK]', '<water_glass>'], ['[PUTBACK]', '<water_glass>', '<table>']]
# 適合率：0.000
# 再現率：0.000
# 適合率（アクション）：1.000
# 再現率（アクション）：0.667
# 適合率（オブジェクト）：0.000
# 再現率（オブジェクト）：0.000
# executable\file180_2.txt
# 入力文：Find the light circuit breaker in the kitchen
# 出力アクション
# []
# 正解アクション
# [['[STANDUP]'], ['[WALK]', '<dining_room>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>']]
# Error
# executable\file182_1.txt
# 入力文：Sit up and type on the keyboard
# 出力アクション
# []
# 正解アクション
# [['[FIND]', '<keyboard>'], ['[GRAB]', '<keyboard>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# Error
# executable\file185_2.txt
# 入力文：walk into office, sit in chair, turn on computer, write email
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<desk>'], ['[FIND]', '<chair>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<chair>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 適合率：0.500
# 再現率：0.500
# 適合率（アクション）：0.833
# 再現率（アクション）：0.833
# 適合率（オブジェクト）：0.600
# 再現率（オブジェクト）：0.500
# executable\file192_1.txt
# 入力文：Take a book from the shelf, sit on sofa and start reading.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>'], ['[GRAB]', '<novel>'], ['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[FIND]', '<novel>'], ['[GRAB]', '<novel>'], ['[READ]', '<novel>']]
# 適合率：0.250
# 再現率：0.400
# 適合率（アクション）：0.250
# 再現率（アクション）：0.400
# 適合率（オブジェクト）：0.750
# 再現率（オブジェクト）：0.600
# executable\file198_1.txt
# 入力文：Sit down on chair in front of computer, turn on computer, find mouse.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<chair>'], ['[FIND]', '<chair>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>'], ['[WALK]', '<mouse>'], ['[FIND]', '<mouse>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<chair>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>'], ['[FIND]', '<mouse>'], ['[GRAB]', '<mouse>'], ['[TURNTO]', '<computer>'], ['[LOOKAT]', '<computer>']]
# 適合率：0.625
# 再現率：0.500
# 適合率（アクション）：0.750
# 再現率（アクション）：0.600
# 適合率（オブジェクト）：0.625
# 再現率（オブジェクト）：0.500
# executable\file203_1.txt
# 入力文：Putting groceries in refridgerator
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>'], ['[WALK]', '<freezer>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>'], ['[GRAB]', '<food_food>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[PUTIN]', '<food_food>', '<freezer>'], ['[CLOSE]', '<freezer>']]
# 適合率：0.667
# 再現率：0.500
# 適合率（アクション）：0.833
# 再現率（アクション）：0.625
# 適合率（オブジェクト）：0.667
# 再現率（オブジェクト）：0.500
# executable\file205_1.txt
# 入力文：Walk into the bedroom and walk to the light switch. Flip the switch.
# 出力アクション
# [['[WALK]', '<bedroom>']]
# 正解アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>']]
# 適合率：1.000
# 再現率：0.250
# 適合率（アクション）：1.000
# 再現率（アクション）：0.250
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.250
# executable\file211_1.txt
# 入力文：I walk over to the phone and pick it up.
# 出力アクション
# [['[WALK]', '<bedroom>']]
# 正解アクション
# [['[WALK]', '<phone>'], ['[GRAB]', '<phone>']]
# 適合率：0.000
# 再現率：0.000
# 適合率（アクション）：1.000
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：0.000
# 再現率（オブジェクト）：0.000
# executable\file222_1.txt
# 入力文：walk into living room, walk to light, turn on light switch.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>'], ['[SWITCHON]', '<light>']]
# 適合率：1.000
# 再現率：0.667
# 適合率（アクション）：1.000
# 再現率（アクション）：0.667
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.667
# executable\file225_2.txt
# 入力文：Sit down, turn on the TV with the remote control that is on the coffee table.
# 出力アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[FIND]', '<coffee_table>'], ['[TURNTO]', '<coffee_table>'], ['[LOOKAT]', '<coffee_table>'], ['[FIND]', '<remote_control>'], ['[GRAB]', '<remote_control>'], ['[FIND]', '<television>'], ['[TURNTO]', '<television>'], ['[LOOKAT]', '<television>'], ['[TURNTO]', '<television>'], ['[POINTAT]', '<television>'], ['[SWITCHON]', '<television>']]
# 適合率：0.500
# 再現率：0.133
# 適合率（アクション）：1.000
# 再現率（アクション）：0.267
# 適合率（オブジェクト）：0.750
# 再現率（オブジェクト）：0.200
# executable\file232_2.txt
# 入力文：I need to turn on the lights in the kitchen so I can make dinner.
# 出力アクション
# [['[WALK]', '<light>'], ['[FIND]', '<light>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[TURNTO]', '<light>'], ['[LOOKAT]', '<light>'], ['[SWITCHON]', '<light>'], ['[WALK]', '<light>'], ['[SWITCHON]', '<light>'], ['[WALK]', '<light>'], ['[SWITCHON]', '<light>']]
# 適合率：1.000
# 再現率：0.200
# 適合率（アクション）：1.000
# 再現率（アクション）：0.200
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.200
# executable\file241_1.txt
# 入力文：Find phone. Move to phone. Pick the phone up.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[FIND]', '<phone>']]
# 正解アクション
# [['[FIND]', '<phone>'], ['[GRAB]', '<phone>']]
# 適合率：0.500
# 再現率：0.500
# 適合率（アクション）：0.500
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：0.500
# 再現率（オブジェクト）：0.500
# executable\file241_2.txt
# 入力文：Find book. Pick up book. Open book. Read the book.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>'], ['[WALK]', '<novel>'], ['[WALK]', '<novel>'], ['[GRAB]', '<novel>'], ['[READ]', '<novel>']]
# 正解アクション
# [['[STANDUP]'], ['[WALK]', '<home_office>'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>'], ['[GRAB]', '<novel>'], ['[TURNTO]', '<novel>'], ['[LOOKAT]', '<novel>'], ['[READ]', '<novel>']]
# 適合率：0.000
# 再現率：0.000
# 適合率（アクション）：0.714
# 再現率（アクション）：0.625
# 適合率（オブジェクト）：0.000
# 再現率（オブジェクト）：0.000
# executable\file247_1.txt
# 入力文：Find groceries. Grab groceries. Walk to refrigerator. Open refrigerator door. Place groceries into refrigerator. Close refrigerator door.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>'], ['[WALK]', '<food_food>'], ['[WALK]', '<dining_room>'], ['[WALK]', '<freezer>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>'], ['[GRAB]', '<food_food>'], ['[WALK]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[PUTIN]', '<food_food>', '<freezer>'], ['[CLOSE]', '<freezer>']]
# 適合率：0.500
# 再現率：0.375
# 適合率（アクション）：0.667
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：0.667
# 再現率（オブジェクト）：0.500
# executable\file259_1.txt
# 入力文：stand up, walk to living room, find remote control, grab remote control, find couch, walk to couch, sit in couch, find television, lift remote control, switch on television, look at television
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[STANDUP]'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[TURNTO]', '<television>'], ['[LOOKAT]', '<television>']]
# 正解アクション
# [['[STANDUP]'], ['[WALK]', '<home_office>'], ['[WALK]', '<remote_control>'], ['[FIND]', '<remote_control>'], ['[GRAB]', '<remote_control>'], ['[FIND]', '<couch>'], ['[WALK]', '<couch>'], ['[SIT]', '<couch>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[TURNTO]', '<television>'], ['[LOOKAT]', '<television>']]
# 適合率：0.500
# 再現率：0.417
# 適合率（アクション）：0.800
# 再現率（アクション）：0.667
# 適合率（オブジェクト）：0.000
# 再現率（オブジェクト）：0.000
# executable\file263_2.txt
# 入力文：Turn on computer, pull up browser, browse the internet
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>'], ['[TURNTO]', '<computer>'], ['[LOOKAT]', '<computer>']]
# 適合率：0.750
# 再現率：0.500
# 適合率（アクション）：1.000
# 再現率（アクション）：0.667
# 適合率（オブジェクト）：0.750
# 再現率（オブジェクト）：0.500
# executable\file264_1.txt
# 入力文：Enter office. Go to desk. Pick up phone.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<desk>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<desk>'], ['[FIND]', '<phone>'], ['[GRAB]', '<phone>']]
# 適合率：0.500
# 再現率：0.250
# 適合率（アクション）：1.000
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：0.500
# 再現率（オブジェクト）：0.250
# executable\file267_1.txt
# 入力文：Walk to kitchen counter, grab a grocery, walk to fridge, open fridge, put the grocery into fridge, and close fridge
# 出力アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<kitchen_counter>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<kitchen_counter>'], ['[FIND]', '<food_food>'], ['[GRAB]', '<food_food>'], ['[WALK]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[PUTIN]', '<food_food>', '<freezer>'], ['[CLOSE]', '<freezer>']]
# 適合率：1.000
# 再現率：0.250
# 適合率（アクション）：1.000
# 再現率（アクション）：0.250
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.250
# executable\file268_1.txt
# 入力文：I walk into the living room and turn on the light. I walk to the couch then sit on the couch.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>'], ['[WALK]', '<couch>'], ['[SIT]', '<couch>']]
# 適合率：0.833
# 再現率：0.833
# 適合率（アクション）：0.833
# 再現率（アクション）：0.833
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.833
# executable\file273_2.txt
# 入力文：Switch on computer. Connect to internet. Login email. Write text body and send mail.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>'], ['[FIND]', '<keyboard>'], ['[TOUCH]', '<keyboard>']]
# 適合率：0.500
# 再現率：0.500
# 適合率（アクション）：0.500
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：0.500
# 再現率（オブジェクト）：0.500
# executable\file274_2.txt
# 入力文：Sit in the desk, switch on the computer and click in the browser application
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<desk>'], ['[FIND]', '<desk>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<chair>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>'], ['[FIND]', '<computer>'], ['[TURNTO]', '<computer>'], ['[LOOKAT]', '<computer>']]
# 適合率：0.333
# 再現率：0.222
# 適合率（アクション）：0.833
# 再現率（アクション）：0.556
# 適合率（オブジェクト）：0.500
# 再現率（オブジェクト）：0.333
# executable\file282_1.txt
# 入力文：Walk to the Home Office.  Find the computer.  Turn on the computer.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 適合率：1.000
# 再現率：1.000
# 適合率（アクション）：1.000
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file287_2.txt
# 入力文：Locate the phone.  Extend arm toward the phone and open hand.  Place hand on phone and close fingers around phone.  Lift phone.
# Error
# executable\file298_2.txt
# 入力文：I leave the bags with groceries near the fridge, open the door and put the groceries in the shelves.
# 出力アクション
# [['[WALK]', '<door>'], ['[FIND]', '<door>'], ['[WALK]', '<home_office>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>'], ['[GRAB]', '<food_food>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[PUTIN]', '<food_food>', '<freezer>']]
# 適合率：0.400
# 再現率：0.286
# 適合率（アクション）：0.600
# 再現率（アクション）：0.429
# 適合率（オブジェクト）：0.400
# 再現率（オブジェクト）：0.286
# executable\file300_1.txt
# 入力文：Go to living room.  Find sofa.  Sit on sofa.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 適合率：1.000
# 再現率：1.000
# 適合率（アクション）：1.000
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file305_2.txt
# 入力文：I go to the bedroom and sit at my desk. I turn my radio on and listen to music.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<desk>'], ['[FIND]', '<desk>'], ['[WALK]', '<stereo>'], ['[FIND]', '<stereo>'], ['[SWITCHON]', '<stereo>']]
# 正解アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>'], ['[WALK]', '<desk>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[FIND]', '<stereo>'], ['[SWITCHON]', '<stereo>']]
# 適合率：0.667
# 再現率：0.444
# 適合率（アクション）：1.000
# 再現率（アクション）：0.667
# 適合率（オブジェクト）：0.800
# 再現率（オブジェクト）：0.444
# executable\file306_2.txt
# 入力文：I come home and go to the sofa for turn off the tv and relax
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[SIT]', '<couch>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>']]
# 適合率：0.667
# 再現率：0.400
# 適合率（アクション）：1.000
# 再現率（アクション）：0.600
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.600
# executable\file307_2.txt
# 入力文：I go into the living room. I find the remote. I turn on the tv. I sit on the couch and watch tv.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[FIND]', '<remote_control>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[WATCH]', '<television>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<remote_control>'], ['[FIND]', '<remote_control>'], ['[FIND]', '<television>'], ['[TURNTO]', '<television>'], ['[POINTAT]', '<television>'], ['[SWITCHON]', '<television>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[TURNTO]', '<television>'], ['[WATCH]', '<television>']]
# 適合率：0.778
# 再現率：0.636
# 適合率（アクション）：0.778
# 再現率（アクション）：0.636
# 適合率（オブジェクト）：0.889
# 再現率（オブジェクト）：0.727
# executable\file310_1.txt
# 入力文：I enter the bedroom and find the light. Then I turn it on.
# 出力アクション
# [['[WALK]', '<light>'], ['[FIND]', '<light>']]
# 正解アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>']]
# 適合率：1.000
# 再現率：0.500
# 適合率（アクション）：1.000
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.500
# executable\file321_1.txt
# 入力文：Drink a glass of water in the sofa
# 出力アクション
# [['[WALK]', '<cup>'], ['[FIND]', '<cup>'], ['[GRAB]', '<cup>'], ['[DRINK]', '<cup>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[FIND]', '<water_glass>'], ['[GRAB]', '<water_glass>'], ['[DRINK]', '<water_glass>']]
# 適合率：0.000
# 再現率：0.000
# 適合率（アクション）：1.000
# 再現率（アクション）：0.571
# 適合率（オブジェクト）：0.000
# 再現率（オブジェクト）：0.000
# executable\file323_2.txt
# 入力文：Walk to the bathroom.  Find the toilet.  Lift the top of the toilet.  Sit on the toilet.
# 出力アクション
# [['[WALK]', '<bathroom>'], ['[WALK]', '<toilet>'], ['[FIND]', '<toilet>'], ['[SIT]', '<toilet>']]
# 正解アクション
# [['[WALK]', '<bathroom>'], ['[WALK]', '<toilet>'], ['[FIND]', '<toilet>'], ['[OPEN]', '<toilet>'], ['[SIT]', '<toilet>']]
# 適合率：1.000
# 再現率：0.800
# 適合率（アクション）：1.000
# 再現率（アクション）：0.800
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.800
# executable\file32_1.txt
# 入力文：I switch on the stove and cook my groceries there.
# 出力アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<oven>'], ['[FIND]', '<oven>'], ['[SWITCHON]', '<oven>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<oven>'], ['[FIND]', '<oven>'], ['[SWITCHON]', '<oven>'], ['[FIND]', '<bowl>'], ['[GRAB]', '<bowl>'], ['[PUTBACK]', '<bowl>', '<oven>'], ['[FIND]', '<food_food>'], ['[SWITCHOFF]', '<oven>']]
# 適合率：1.000
# 再現率：0.444
# 適合率（アクション）：1.000
# 再現率（アクション）：0.444
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.444
# executable\file331_2.txt
# 入力文：switching on light in an area
# 出力アクション
# [['[WALK]', '<light>'], ['[FIND]', '<light>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>']]
# 適合率：1.000
# 再現率：0.500
# 適合率（アクション）：1.000
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.500
# executable\file332_2.txt
# 入力文：I walk into the living room. I cross the room to the couch. I sit down and relax.
# 出力アクション
# [['[WALK]', '<home_office>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[SIT]', '<couch>']]
# 適合率：1.000
# 再現率：0.333
# 適合率（アクション）：1.000
# 再現率（アクション）：0.333
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.333
# executable\file342_2.txt
# 入力文：Turn on the TV, sit on the couch, find a show, and watch it.
# 出力アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[FIND]', '<remote_control>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[SWITCHON]', '<television>'], ['[TURNTO]', '<television>'], ['[LOOKAT]', '<television>']]
# 適合率：0.375
# 再現率：0.333
# 適合率（アクション）：0.500
# 再現率（アクション）：0.444
# 適合率（オブジェクト）：0.375
# 再現率（オブジェクト）：0.333
# executable\file345_1.txt
# 入力文：We enter into the Living room and walk towards light switch. Then switch on the light.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>'], ['[FIND]', '<light>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<filing_cabinet>'], ['[FIND]', '<remote_control>'], ['[GRAB]', '<remote_control>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>']]
# 適合率：0.667
# 再現率：0.333
# 適合率（アクション）：1.000
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.500
# executable\file349_2.txt
# 入力文：I go to the home office to find the computer. I turn switch computer on , i open the email. i write the email and  send it.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 適合率：1.000
# 再現率：0.750
# 適合率（アクション）：1.000
# 再現率（アクション）：0.750
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.750
# executable\file352_1.txt
# 入力文：find the phone and pick it up
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[FIND]', '<phone>']]
# 正解アクション
# [['[FIND]', '<table>'], ['[TURNTO]', '<table>'], ['[LOOKAT]', '<table>'], ['[FIND]', '<phone>'], ['[TURNTO]', '<phone>'], ['[LOOKAT]', '<phone>'], ['[GRAB]', '<phone>']]
# 適合率：0.500
# 再現率：0.143
# 適合率（アクション）：0.500
# 再現率（アクション）：0.143
# 適合率（オブジェクト）：0.500
# 再現率（オブジェクト）：0.143
# executable\file360_1.txt
# 入力文：i go find the phone. i pick up the phone
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[FIND]', '<phone>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<phone>'], ['[FIND]', '<phone>'], ['[GRAB]', '<phone>']]
# 適合率：0.500
# 再現率：0.250
# 適合率（アクション）：1.000
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：0.500
# 再現率（オブジェクト）：0.250
# executable\file360_2.txt
# 入力文：i go to the bathroom. I find the toilet
# 出力アクション
# [['[WALK]', '<bathroom>'], ['[WALK]', '<toilet>'], ['[FIND]', '<toilet>']]
# 正解アクション
# [['[WALK]', '<bathroom>'], ['[WALK]', '<toilet>'], ['[FIND]', '<toilet>']]
# 適合率：1.000
# 再現率：1.000
# 適合率（アクション）：1.000
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file365_1.txt
# 入力文：For browsing internet walk to home office. Find Computer. Walk to Computer. Find Chair. Sit in a chair and switch on computer. Connect with internet and browse the net.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[WALK]', '<computer>'], ['[WALK]', '<chair>'], ['[FIND]', '<chair>'], ['[WALK]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[WALK]', '<computer>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[SWITCHON]', '<computer>']]
# 適合率：0.625
# 再現率：0.714
# 適合率（アクション）：0.750
# 再現率（アクション）：0.857
# 適合率（オブジェクト）：0.857
# 再現率（オブジェクト）：0.857
# executable\file371_1.txt
# 入力文：I go to my desk. I turn on the computer. I open a web page and look at it.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<desk>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>'], ['[TURNTO]', '<computer>'], ['[LOOKAT]', '<computer>']]
# 適合率：0.600
# 再現率：0.500
# 適合率（アクション）：0.800
# 再現率（アクション）：0.667
# 適合率（オブジェクト）：0.600
# 再現率（オブジェクト）：0.500
# executable\file373_1.txt
# 入力文：go to home office. turn the computer on. begin working
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 適合率：1.000
# 再現率：1.000
# 適合率（アクション）：1.000
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file377_2.txt
# 入力文：Walk into the living room/den. Turn on the television. Switch channels to find a program with remote. I find a program and look at the screen.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[FIND]', '<remote_control>'], ['[TURNTO]', '<remote_control>'], ['[TURNTO]', '<television>'], ['[LOOKAT]', '<television>']]
# 適合率：1.000
# 再現率：0.500
# 適合率（アクション）：1.000
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.500
# executable\file385_1.txt
# 入力文：Walk to home office. Find computer. Sit in chair in front of computer desk. Turn on computer. Open internet browser. Browse the internet
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[STANDUP]'], ['[WALK]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[WALK]', '<desk>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[SWITCHON]', '<computer>']]
# 適合率：0.750
# 再現率：0.857
# 適合率（アクション）：0.750
# 再現率（アクション）：0.857
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.857
# executable\file385_2.txt
# 入力文：Go to living room. Find CD player. Pick CD. Put CD in CD player. Play music.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<stereo>'], ['[FIND]', '<stereo>'], ['[WALK]', '<candle>'], ['[FIND]', '<candle>'], ['[GRAB]', '<candle>'], ['[WALK]', '<stereo>']]
# 正解アクション
# [['[FIND]', '<cd_player>'], ['[WALK]', '<cd_player>'], ['[SWITCHON]', '<cd_player>']]
# 適合率：0.000
# 再現率：0.000
# 適合率（アクション）：0.143
# 再現率（アクション）：0.333
# 適合率（オブジェクト）：0.000
# 再現率（オブジェクト）：0.000
# executable\file387_1.txt
# 入力文：Walk to living room. Find couch. Sit on couch
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 適合率：1.000
# 再現率：1.000
# 適合率（アクション）：1.000
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file388_1.txt
# 入力文：Find phone. Walk to phone. Pick up phone. Answer call with a greeting.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[FIND]', '<phone>']]
# 正解アクション
# [['[FIND]', '<phone>'], ['[WALK]', '<home_office>'], ['[WALK]', '<phone>'], ['[GRAB]', '<phone>']]
# 適合率：0.500
# 再現率：0.250
# 適合率（アクション）：0.500
# 再現率（アクション）：0.250
# 適合率（オブジェクト）：0.500
# 再現率（オブジェクト）：0.250
# executable\file390_2.txt
# 入力文：Walk into the living room. Walk up to the sofa. Sit down on the sofa.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[SIT]', '<couch>']]
# 適合率：0.750
# 再現率：1.000
# 適合率（アクション）：0.750
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file392_1.txt
# 入力文：find lightswitch. walk to light switch. turn on light.
# 出力アクション
# [['[WALK]', '<light>'], ['[FIND]', '<light>']]
# 正解アクション
# [['[FIND]', '<light>'], ['[WALK]', '<light>'], ['[SWITCHON]', '<light>']]
# 適合率：0.500
# 再現率：0.333
# 適合率（アクション）：0.500
# 再現率（アクション）：0.333
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.667
# executable\file393_1.txt
# 入力文："I walk to the entrance hall"  "I walk to the home office"  "I look for desk" "I find the desk" "I look for chair" "Ifind the chair" "I look for computer" "I find the computer" I sit in Chair"  "I switch on to the computer"  "I browse the internet"
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<desk>'], ['[FIND]', '<desk>'], ['[FIND]', '<chair>'], ['[FIND]', '<computer>'], ['[SIT]', '<chair>'], ['[STANDUP]'], ['[WALK]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<home_office>'], ['[WALK]', '<desk>'], ['[FIND]', '<desk>'], ['[TURNTO]', '<desk>'], ['[LOOKAT]', '<desk>'], ['[FIND]', '<desk>'], ['[FIND]', '<chair>'], ['[TURNTO]', '<chair>'], ['[LOOKAT]', '<chair>'], ['[FIND]', '<chair>'], ['[FIND]', '<computer>'], ['[TURNTO]', '<computer>'], ['[LOOKAT]', '<computer>'], ['[FIND]', '<computer>'], ['[SIT]', '<chair>'], ['[SWITCHON]', '<computer>'], ['[WATCH]', '<computer>']]
# 適合率：0.778
# 再現率：0.389
# 適合率（アクション）：0.778
# 再現率（アクション）：0.389
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.444
# executable\file394_1.txt
# 入力文：Find the computer. Switch on. Point to browser.  Open browser.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>']]
# 正解アクション
# [['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 適合率：0.333
# 再現率：0.500
# 適合率（アクション）：0.333
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：0.667
# 再現率（オブジェクト）：1.000
# executable\file394_2.txt
# 入力文：Find light switch. switch on
# 出力アクション
# []
# 正解アクション
# [['[FIND]', '<light>'], ['[SWITCHON]', '<light>']]
# Error
# executable\file3_1.txt
# 入力文：I go to the living room and sit in the sofa
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[WALK]', '<couch>'], ['[SIT]', '<couch>']]
# 適合率：1.000
# 再現率：0.800
# 適合率（アクション）：1.000
# 再現率（アクション）：0.800
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.800
# executable\file403_1.txt
# 入力文：I walk into my room and turn the radio on so that I can listen to music.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<stereo>'], ['[FIND]', '<stereo>'], ['[SWITCHON]', '<stereo>']]
# 正解アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<stereo>'], ['[FIND]', '<stereo>'], ['[SWITCHON]', '<stereo>']]
# 適合率：1.000
# 再現率：1.000
# 適合率（アクション）：1.000
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file411_1.txt
# 入力文：Walk to Living room. Find Television. Walk to sofa. Sit on sofa. Find Remote. Grab remote. Turn to television. Look at television. Switch on Television.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[STANDUP]'], ['[WALK]', '<television>'], ['[TURNTO]', '<television>'], ['[LOOKAT]', '<television>'], ['[SWITCHON]', '<television>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[WALK]', '<couch>'], ['[SIT]', '<couch>'], ['[FIND]', '<remote_control>'], ['[GRAB]', '<remote_control>'], ['[TURNTO]', '<television>'], ['[LOOKAT]', '<television>'], ['[SWITCHON]', '<television>']]
# 適合率：0.727
# 再現率：0.800
# 適合率（アクション）：0.727
# 再現率（アクション）：0.800
# 適合率（オブジェクト）：0.889
# 再現率（オブジェクト）：0.800
# executable\file436_1.txt
# 入力文：walk to living room, walk to the phone reach for the phone and pick up the phone.
# 出力アクション
# [['[WALK]', '<home_office>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<phone>'], ['[FIND]', '<phone>'], ['[TOUCH]', '<phone>'], ['[GRAB]', '<phone>']]
# 適合率：1.000
# 再現率：0.200
# 適合率（アクション）：1.000
# 再現率（アクション）：0.200
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.200
# executable\file441_2.txt
# 入力文：Walk to the room, in which the TV is located. Turn on TV pressing the power button for the TV. Watch TV.
# 出力アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[WATCH]', '<television>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>']]
# 適合率：0.600
# 再現率：0.750
# 適合率（アクション）：0.800
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：0.750
# 再現率（オブジェクト）：0.750
# executable\file442_1.txt
# 入力文：Find the sofa and sit on it.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 適合率：1.000
# 再現率：1.000
# 適合率（アクション）：1.000
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file442_2.txt
# 入力文：Find the phone and grab it.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[FIND]', '<phone>'], ['[GRAB]', '<phone>']]
# 正解アクション
# [['[FIND]', '<phone>'], ['[GRAB]', '<phone>']]
# 適合率：0.667
# 再現率：1.000
# 適合率（アクション）：0.667
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：0.667
# 再現率（オブジェクト）：1.000
# executable\file445_1.txt
# 入力文：Walk to living room, go to a light switch button, press button, confirm the light is on, go to next light switch button, press button, confirm the light is on
# 出力アクション
# [['[WALK]', '<home_office>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>'], ['[SWITCHON]', '<light>'], ['[FIND]', '<light>'], ['[TURNTO]', '<light>'], ['[LOOKAT]', '<light>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>'], ['[TURNTO]', '<light>'], ['[LOOKAT]', '<light>']]
# 適合率：1.000
# 再現率：0.100
# 適合率（アクション）：1.000
# 再現率（アクション）：0.100
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.100
# executable\file446_1.txt
# 入力文：Go find a computer, turn it on, click google, and browse the internet.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>'], ['[TURNTO]', '<computer>'], ['[LOOKAT]', '<computer>']]
# 適合率：0.750
# 再現率：0.500
# 適合率（アクション）：1.000
# 再現率（アクション）：0.667
# 適合率（オブジェクト）：0.750
# 再現率（オブジェクト）：0.500
# executable\file447_2.txt
# 入力文：you walk to the living room, open the door, find a comfy sofa, sit on it, read a book or sip a cup of coffee and relax.
# 出力アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<door>'], ['[FIND]', '<door>'], ['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[STANDUP]'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>'], ['[GRAB]', '<novel>'], ['[READ]', '<novel>'], ['[WALK]', '<bathroom>'], ['[WALK]', '<cup>'], ['[FIND]', '<cup>'], ['[GRAB]', '<cup>'], ['[DRINK]', '<cup>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[FIND]', '<coffee_cup>'], ['[GRAB]', '<coffee_cup>'], ['[SIT]', '<couch>'], ['[FIND]', '<novel>'], ['[GRAB]', '<novel>'], ['[READ]', '<novel>'], ['[DRINK]', '<coffee_cup>']]
# 適合率：0.412
# 再現率：0.700
# 適合率（アクション）：0.529
# 再現率（アクション）：0.900
# 適合率（オブジェクト）：0.438
# 再現率（オブジェクト）：0.700
# executable\file454_2.txt
# 入力文：Walk to the living room. Sit on the sofa. Grab the remote and turn on the television.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>'], ['[STANDUP]'], ['[WALK]', '<remote_control>'], ['[FIND]', '<remote_control>'], ['[GRAB]', '<remote_control>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[SIT]', '<couch>'], ['[FIND]', '<remote_control>'], ['[GRAB]', '<remote_control>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[TURNTO]', '<television>'], ['[WATCH]', '<television>']]
# 適合率：0.700
# 再現率：0.778
# 適合率（アクション）：0.500
# 再現率（アクション）：0.556
# 適合率（オブジェクト）：0.778
# 再現率（オブジェクト）：0.778
# executable\file455_1.txt
# 入力文：I walk to the living room and find the sofa. I sit on the sofa and get comfortable.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 適合率：1.000
# 再現率：1.000
# 適合率（アクション）：1.000
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file463_2.txt
# 入力文：I walk into the bedroom. I walk to stereo. I turn on stereo.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<stereo>'], ['[WALK]', '<stereo>'], ['[FIND]', '<stereo>'], ['[SWITCHON]', '<stereo>']]
# 正解アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<stereo>'], ['[SWITCHON]', '<stereo>']]
# 適合率：0.600
# 再現率：1.000
# 適合率（アクション）：0.600
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file474_2.txt
# 入力文：Find the phone and grab it.
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[FIND]', '<phone>'], ['[GRAB]', '<phone>']]
# 正解アクション
# [['[FIND]', '<phone>'], ['[GRAB]', '<phone>']]
# 適合率：0.667
# 再現率：1.000
# 適合率（アクション）：0.667
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：0.667
# 再現率（オブジェクト）：1.000
# executable\file475_2.txt
# 入力文：I walk into home office. I walk to desk. I sit at chair. I turn on computer.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<desk>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[STANDUP]'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<desk>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# 適合率：0.857
# 再現率：1.000
# 適合率（アクション）：0.857
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file478_1.txt
# 入力文：I walk into the bath room and go to the toilet
# 出力アクション
# [['[WALK]', '<bathroom>'], ['[WALK]', '<toilet>']]
# 正解アクション
# [['[WALK]', '<bathroom>'], ['[WALK]', '<toilet>'], ['[FIND]', '<toilet>'], ['[SIT]', '<toilet>']]
# 適合率：1.000
# 再現率：0.500
# 適合率（アクション）：1.000
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.500
# executable\file484_1.txt
# 入力文：I walk into the living room. I pick up a book. I sit down in a chair and read the book.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>'], ['[WALK]', '<chair>'], ['[FIND]', '<chair>'], ['[WALK]', '<novel>'], ['[GRAB]', '<novel>'], ['[READ]', '<novel>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>'], ['[GRAB]', '<novel>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[READ]', '<novel>']]
# 適合率：0.625
# 再現率：0.714
# 適合率（アクション）：0.625
# 再現率（アクション）：0.714
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.857
# executable\file490_1.txt
# 入力文：walk to living room, walk to sofa, sit in sofa
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[SIT]', '<couch>']]
# 適合率：0.750
# 再現率：1.000
# 適合率（アクション）：0.750
# 再現率（アクション）：1.000
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file496_1.txt
# ...
# 適合率：0.000
# 再現率：0.000
# 適合率（アクション）：1.000
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：0.000
# 再現率（オブジェクト）：0.000
# executable\file874_2.txt
# 入力文：I walk towards to the bedroom, and I open the door of the bedroom, and I switch on the lights inside the bedroom, the switch is beside the door.
# 出力アクション
# [['[WALK]', '<door>'], ['[FIND]', '<door>'], ['[FIND]', '<light>']]
# 正解アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[SWITCHON]', '<light>']]
# 適合率：0.333
# 再現率：0.250
# 適合率（アクション）：0.667
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：0.333
# 再現率（オブジェクト）：0.250
# executable\file88_1.txt
# 入力文：Walk to living-room. Look at the desk where Computer stays. Sit in chair. Switch on computer. Work on computer. Switch off computer.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<desk>'], ['[FIND]', '<desk>'], ['[TURNTO]', '<desk>'], ['[LOOKAT]', '<desk>'], ['[WALK]', '<chair>'], ['[FIND]', '<chair>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>'], ['[WALK]', '<computer>'], ['[WALK]', '<computer>'], ['[SWITCHOFF]', '<computer>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<desk>'], ['[FIND]', '<desk>'], ['[TURNTO]', '<desk>'], ['[LOOKAT]', '<desk>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>'], ['[TURNTO]', '<computer>'], ['[WATCH]', '<computer>'], ['[SWITCHOFF]', '<computer>']]
# 適合率：0.692
# 再現率：0.750
# 適合率（アクション）：0.692
# 再現率（アクション）：0.750
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：1.000
# executable\file897_1.txt
# 入力文：find groceries, grab that groceries, walk to dining room, look at the fridge, open the fridge door, put the groceries into fridge, close the fridge
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>'], ['[WALK]', '<dining_room>'], ['[WALK]', '<freezer>'], ['[FIND]', '<freezer>'], ['[TURNTO]', '<freezer>'], ['[LOOKAT]', '<freezer>'], ['[WALK]', '<freezer>']]
# 正解アクション
# [['[FIND]', '<food_food>'], ['[GRAB]', '<food_food>'], ['[WALK]', '<dining_room>'], ['[WALK]', '<freezer>'], ['[FIND]', '<freezer>'], ['[TURNTO]', '<freezer>'], ['[LOOKAT]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[PUTIN]', '<food_food>', '<freezer>'], ['[CLOSE]', '<freezer>']]
# 適合率：0.667
# 再現率：0.600
# 適合率（アクション）：0.556
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：0.889
# 再現率（オブジェクト）：0.800
# executable\file897_2.txt
# 入力文：walk to home office, look at the light switch board, switch on the light, find the book, grap the book, sit in the chair, put the book into table, open the book, now read the book
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[WALK]', '<novel>'], ['[FIND]', '<novel>'], ['[WALK]', '<chair>'], ['[FIND]', '<chair>'], ['[WALK]', '<novel>'], ['[WALK]', '<novel>'], ['[GRAB]', '<novel>'], ['[READ]', '<novel>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<light>'], ['[FIND]', '<light>'], ['[TURNTO]', '<light>'], ['[LOOKAT]', '<light>'], ['[SWITCHON]', '<light>'], ['[FIND]', '<novel>'], ['[GRAB]', '<novel>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[FIND]', '<table>'], ['[PUTBACK]', '<novel>', '<table>'], ['[GRAB]', '<novel>'], ['[READ]', '<novel>']]
# 適合率：0.636
# 再現率：0.500
# 適合率（アクション）：0.636
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.714
# executable\file89_1.txt
# 入力文：I take the groceries out of the grocery bags, throw away grocery bags, categorize the food so that I know where it goes in the fridge, open the fridge, and place each item in the fridge before closing the fridge.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>'], ['[WALK]', '<dining_room>'], ['[WALK]', '<freezer>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[WALK]', '<freezer>'], ['[WALK]', '<freezer>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<freezer>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[FIND]', '<food_food>'], ['[GRAB]', '<food_food>'], ['[PUTIN]', '<food_food>', '<freezer>'], ['[CLOSE]', '<freezer>']]
# 適合率：0.111
# 再現率：0.125
# 適合率（アクション）：0.444
# 再現率（アクション）：0.500
# 適合率（オブジェクト）：0.222
# 再現率（オブジェクト）：0.250
# executable\file8_1.txt
# 入力文：I get my groceries and go to the fridge. I open the fridge and put the groceries there.
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>'], ['[WALK]', '<dining_room>'], ['[WALK]', '<freezer>'], ['[WALK]', '<freezer>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>']]
# 正解アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<food_food>'], ['[FIND]', '<food_food>'], ['[GRAB]', '<food_food>'], ['[FIND]', '<freezer>'], ['[OPEN]', '<freezer>'], ['[PUTIN]', '<food_food>', '<freezer>'], ['[CLOSE]', '<freezer>']]
# 適合率：0.500
# 再現率：0.500
# 適合率（アクション）：0.625
# 再現率（アクション）：0.625
# 適合率（オブジェクト）：0.500
# 再現率（オブジェクト）：0.500
# executable\file910_1.txt
# 入力文：Work on computer
# 出力アクション
# []
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<chair>'], ['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>']]
# Error
# executable\file928_1.txt
# 入力文：Sit at computer and surf the web
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[WALK]', '<computer>'], ['[FIND]', '<computer>']]
# 正解アクション
# [['[FIND]', '<chair>'], ['[SIT]', '<chair>'], ['[FIND]', '<mouse>'], ['[GRAB]', '<mouse>'], ['[FIND]', '<computer>'], ['[SWITCHON]', '<computer>'], ['[TURNTO]', '<computer>'], ['[LOOKAT]', '<computer>']]
# 適合率：0.333
# 再現率：0.125
# 適合率（アクション）：0.333
# 再現率（アクション）：0.125
# 適合率（オブジェクト）：0.667
# 再現率（オブジェクト）：0.250
# executable\file932_2.txt
# 入力文：walk to living room, find sofa, sit in sofa
# 出力アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[WALK]', '<couch>'], ['[SIT]', '<couch>']]
# 適合率：1.000
# 再現率：0.800
# 適合率（アクション）：1.000
# 再現率（アクション）：0.800
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.800
# executable\file941_2.txt
# 入力文：Open coffee maker. Put filter in main basket, put ground coffee in filter, fill reservoir with water, turn on coffee maker.
# 出力アクション
# [['[WALK]', '<dining_room>'], ['[WALK]', '<coffeemaker>'], ['[FIND]', '<coffeemaker>'], ['[WALK]', '<coffeemaker>'], ['[SWITCHON]', '<coffeemaker>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<couch>'], ['[FIND]', '<couch>'], ['[SIT]', '<couch>']]
# 適合率：0.000
# 再現率：0.000
# 適合率（アクション）：0.600
# 再現率（アクション）：0.750
# 適合率（オブジェクト）：0.000
# 再現率（オブジェクト）：0.000
# executable\file960_2.txt
# 入力文：change tv channel with the remote, then watch the tv
# 出力アクション
# [['[WALK]', '<home_office>'], ['[FIND]', '<remote_control>'], ['[WATCH]', '<remote_control>'], ['[WALK]', '<television>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[WATCH]', '<television>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<remote_control>'], ['[FIND]', '<remote_control>'], ['[GRAB]', '<remote_control>'], ['[FIND]', '<television>'], ['[SWITCHON]', '<television>'], ['[TOUCH]', '<remote_control>'], ['[TURNTO]', '<television>'], ['[WATCH]', '<television>']]
# 適合率：0.714
# 再現率：0.556
# 適合率（アクション）：0.429
# 再現率（アクション）：0.333
# 適合率（オブジェクト）：1.000
# 再現率（オブジェクト）：0.778
# executable\file963_2.txt
# 入力文：walk to phone, grab phone, pick up phone, put to ear
# 出力アクション
# [['[WALK]', '<bedroom>'], ['[FIND]', '<phone>'], ['[GRAB]', '<phone>']]
# 正解アクション
# [['[WALK]', '<home_office>'], ['[WALK]', '<phone>'], ['[FIND]', '<phone>'], ['[GRAB]', '<phone>']]
# 適合率：0.667
# 再現率：0.500
# 適合率（アクション）：1.000
# 再現率（アクション）：0.750
# 適合率（オブジェクト）：0.667
# 再現率（オブジェクト）：0.500
# executable\file974_1.txt
# 入力文：Walk to the entrance hall. Find the telephone. Grab the telephone.
# Error
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\urllib3\connectionpool.py:384, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         except Exception as e:
#     382             # Remove the TypeError from the exception chain in Python 3;
#     383             # otherwise it looks like a programming error was the cause.
# --> 384             six.raise_from(e, None)
#     385 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:2, in raise_from(value, from_value)
#
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\urllib3\connectionpool.py:380, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379 try:
# --> 380     httplib_response = conn.getresponse()
#     381 except Exception as e:
#     382     # Remove the TypeError from the exception chain in Python 3;
#     383     # otherwise it looks like a programming error was the cause.
#
# File ~\Anaconda3\envs\vh2kg\lib\http\client.py:1332, in HTTPConnection.getresponse(self)
#    1331 try:
# -> 1332     response.begin()
#    1333 except ConnectionError:
#
# File ~\Anaconda3\envs\vh2kg\lib\http\client.py:303, in HTTPResponse.begin(self)
#     302 while True:
# --> 303     version, status, reason = self._read_status()
#     304     if status != CONTINUE:
#
# File ~\Anaconda3\envs\vh2kg\lib\http\client.py:264, in HTTPResponse._read_status(self)
#     263 def _read_status(self):
# --> 264     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265     if len(line) > _MAXLINE:
#
# File ~\Anaconda3\envs\vh2kg\lib\socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\requests\adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 if not chunked:
# --> 439     resp = conn.urlopen(
#     440         method=request.method,
#     441         url=url,
#     442         body=request.body,
#     443         headers=request.headers,
#     444         redirect=False,
#     445         assert_same_host=False,
#     446         preload_content=False,
#     447         decode_content=False,
#     448         retries=self.max_retries,
#     449         timeout=timeout
#     450     )
#     452 # Send the request.
#     453 else:
#
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\urllib3\connectionpool.py:637, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     635     e = ProtocolError('Connection aborted.', e)
# --> 637 retries = retries.increment(method, url, error=e, _pool=self,
#     638                             _stacktrace=sys.exc_info()[2])
#     639 retries.sleep()
#
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\urllib3\util\retry.py:368, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     367 if read is False or not self._is_method_retryable(method):
# --> 368     raise six.reraise(type(error), error, _stacktrace)
#     369 elif read is not None:
#
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\urllib3\packages\six.py:686, in reraise(tp, value, tb)
#     685     raise value.with_traceback(tb)
# --> 686 raise value
#
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\urllib3\connectionpool.py:597, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     596 # Make the request on the httplib connection object.
# --> 597 httplib_response = self._make_request(conn, method, url,
#     598                                       timeout=timeout_obj,
#     599                                       body=body, headers=headers,
#     600                                       chunked=chunked)
#     602 # If we're going to release the connection in ``finally:``, then
#     603 # the response doesn't need to know about the connection. Otherwise
#     604 # it will also try to release it and we'll have a double-release
#     605 # mess.
#
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 386     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     387     raise
#
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\urllib3\connectionpool.py:306, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     305 if isinstance(err, SocketTimeout):
# --> 306     raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
#     308 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     309 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPConnectionPool(host='127.0.0.1', port=8080): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~\workspace\virtualhome2kg\simulation\unity_simulator\comm_unity.py:92, in UnityCommunication.post_command(self, request_dict, repeat)
#      91 else:
# ---> 92     resp = requests.post(self._address, json=request_dict, timeout=self.timeout_wait)
#      93 if resp.status_code != requests.codes.ok:
#
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\requests\api.py:116, in post(url, data, json, **kwargs)
#     105 r"""Sends a POST request.
#     106
#     107 :param url: URL for the new :class:`Request` object.
#    (...)
#     113 :rtype: requests.Response
#     114 """
# --> 116 return request('post', url, data=data, json=json, **kwargs)
#
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\requests\api.py:60, in request(method, url, **kwargs)
#      59 with sessions.Session() as session:
# ---> 60     return session.request(method=method, url=url, **kwargs)
#
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\requests\sessions.py:533, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532 send_kwargs.update(settings)
# --> 533 resp = self.send(prep, **send_kwargs)
#     535 return resp
#
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\requests\sessions.py:646, in Session.send(self, request, **kwargs)
#     645 # Send the request
# --> 646 r = adapter.send(request, **kwargs)
#     648 # Total elapsed time of the request (approximately)
#
# File ~\Anaconda3\envs\vh2kg\lib\site-packages\requests\adapters.py:529, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     528 elif isinstance(e, ReadTimeoutError):
# --> 529     raise ReadTimeout(e, request=request)
#     530 else:
#
# ReadTimeout: HTTPConnectionPool(host='127.0.0.1', port=8080): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# UnityCommunicationException               Traceback (most recent call last)
# Input In [37], in <cell line: 18>()
#      16 mistake_objects = []
#      18 for file in files:
# ---> 19     comm.reset(0)
#      20     comm.add_character('Chars/male1', initial_room='bathroom')
#      21     success, graph = comm.environment_graph()
#
# File ~\workspace\virtualhome2kg\simulation\unity_simulator\comm_unity.py:222, in UnityCommunication.reset(self, scene_index)
#     214 def reset(self, scene_index=None):
#     215     """
#     216     Reset scene. Deletes characters and scene chnages, and loads the scene in scene_index
#     217
#    (...)
#     220     :return: succes (bool)
#     221     """
# --> 222     response = self.post_command({'id': str(time.time()), 'action': 'reset',
#     223                                   'intParams': [] if scene_index is None else [scene_index]})
#     224     return response['success']
#
# File ~\workspace\virtualhome2kg\simulation\unity_simulator\comm_unity.py:97, in UnityCommunication.post_command(self, request_dict, repeat)
#      95     return resp.json()
#      96 except requests.exceptions.RequestException as e:
# ---> 97     raise UnityCommunicationException(str(e))
#
# UnityCommunicationException: HTTPConnectionPool(host='127.0.0.1', port=8080): Read timed out. (read timeout=30)

# %%
print(error_files)
# Out:
# ['executable\\file1064_1.txt', 'executable\\file137_1.txt', 'executable\\file145_1.txt', 'executable\\file150_2.txt', 'executable\\file155_2.txt', 'executable\\file180_2.txt', 'executable\\file182_1.txt', 'executable\\file287_2.txt', 'executable\\file394_2.txt', 'executable\\file447_2.txt']

# %%
print("平均　適合率：" + "{:.3f}".format(sum(accuracy_list)/len(accuracy_list)))
print("平均　再現率：" + "{:.3f}".format(sum(recall_list)/len(recall_list)))
print("平均　適合率（アクション）：" + "{:.3f}".format(sum(action_accuracy_list)/len(action_accuracy_list)))
print("平均　再現率（アクション）：" + "{:.3f}".format(sum(action_recall_list)/len(action_recall_list)))
print("平均　適合率（オブジェクト）：" + "{:.3f}".format(sum(object_accuracy_list)/len(object_accuracy_list)))
print("平均　再現率（オブジェクト）：" + "{:.3f}".format(sum(object_recall_list)/len(object_recall_list)))

def get_variance(l, ave):
    total = 0
    for n in l:
        total += (n-ave)*(n-ave)
    return total/len(l)

print("分散　適合率：" + "{:.3f}".format(get_variance(accuracy_list, sum(accuracy_list)/len(accuracy_list))))
print("分散　再現率：" + "{:.3f}".format(get_variance(recall_list, sum(recall_list)/len(recall_list))))
print("分散　適合率（アクション）：" + "{:.3f}".format(get_variance(action_accuracy_list, sum(action_accuracy_list)/len(action_accuracy_list))))
print("分散　再現率（アクション）：" + "{:.3f}".format(get_variance(action_recall_list, sum(action_recall_list)/len(action_recall_list))))
print("分散　適合率（オブジェクト）：" + "{:.3f}".format(get_variance(object_accuracy_list, sum(object_accuracy_list)/len(object_accuracy_list))))
print("分散　再現率（オブジェクト）：" + "{:.3f}".format(get_variance(object_recall_list, sum(object_recall_list)/len(object_recall_list))))

print("error files: " + str(error_files))
print("number of errors: " + str(len(error_files)))
# Out:
# 平均　適合率：0.640
# 平均　再現率：0.523
# 平均　適合率（アクション）：0.778
# 平均　再現率（アクション）：0.624
# 平均　適合率（オブジェクト）：0.752
# 平均　再現率（オブジェクト）：0.568
# 分散　適合率：0.084
# 分散　再現率：0.090
# 分散　適合率（アクション）：0.054
# 分散　再現率（アクション）：0.060
# 分散　適合率（オブジェクト）：0.089
# 分散　再現率（オブジェクト）：0.091
# error files: ['executable\\file1064_1.txt', 'executable\\file137_1.txt', 'executable\\file145_1.txt', 'executable\\file150_2.txt', 'executable\\file155_2.txt', 'executable\\file180_2.txt', 'executable\\file182_1.txt', 'executable\\file287_2.txt', 'executable\\file394_2.txt', 'executable\\file696_1.txt', 'executable\\file701_1.txt', 'executable\\file718_1.txt', 'executable\\file755_1.txt', 'executable\\file910_1.txt', 'executable\\file974_1.txt']
# number of errors: 15
